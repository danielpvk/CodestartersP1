# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# Import the tweepy library
import tweepy


#---------------------------------------------------------------------------------------------------------------------
# wait_on_rate_limit= True;  will make the api to automatically wait for rate limits to replenish
# wait_on_rate_limit_notify= Ture;  will make the api  to print a notification when Tweepyis waiting for rate limits to replenish
#---------------------------------------------------------------------------------------------------------------------


#---------------------------------------------------------------------------------------------------------------------
# The following loop will print most recent statuses, including retweets, posted by the authenticating user and that user’s friends. 
# This is the equivalent of /timeline/home on the Web.
#---------------------------------------------------------------------------------------------------------------------


	
#---------------------------------------------------------------------------------------------------------------------
# Twitter API development use pagination for Iterating through timelines, user lists, direct messages, etc. 
# To help make pagination easier and Tweepy has the Cursor object.

# %%
# Variables that contains the user credentials to access Twitter API 
ACCESS_TOKEN = '54224760-OHpN11y0XuEoycqVaeXj3Bo4m7wFDKoWsAxuNDAdH'
ACCESS_SECRET = 'p4iai7fWiuR3o2gCdzPMEgXkjW4e6wbv7I1MQQKbQ6gzn'
CONSUMER_KEY = 'OcfcqAZGIvtUKWCEO9XfWhCjW'
CONSUMER_SECRET = 'jnFRZ0daR2xdzy7IEjR6ih98ej44UO2ioEkZg95INwtefXyLJU'

# Setup tweepy to authenticate with Twitter credentials:

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# Create the api to connect to twitter with your creadentials
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)
for tweet in tweepy.Cursor(api.search, q="Mexico",lang="es", rpp=1).items():
    print(json.dumps(tweet._json,indent=4,sort_keys=True))

# %%
for status in tweepy.Cursor(api.home_timeline).items(200):
    print(json.dumps(status._json,indent=4,sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:15:02 +0000 2019",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     62,
#                     78
#                 ],
#                 "text": "GuardiaNacional"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1112040549312286720",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/ZJ81DkrNZx"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 211307172,
#                 "id_str": "211307172",
#                 "indices": [
#                     1,
#                     15
#                 ],
#                 "name": "Alfonso Durazo",
#                 "screen_name": "AlfonsoDurazo"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1112040549312286720,
#     "id_str": "1112040549312286720",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "es",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://buffer.com\" rel=\"nofollow\">Buffer</a>",
#     "text": ".@AlfonsoDurazo inform\u00f3 que la meta para fin de a\u00f1o es que la #GuardiaNacional cuente con aproximadamente 80 mil ef\u2026 https://t.co/ZJ81DkrNZx",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Oct 23 15:13:11 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Periodismo independiente con todo el rigor. El sitio de noticias de M\u00e9xico es Animal Pol\u00edtico.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "AnimalPolitico.com",
#                         "expanded_url": "http://AnimalPolitico.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/6FkluWidsv"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 19698,
#         "follow_request_sent": false,
#         "followers_count": 2000062,
#         "following": true,
#         "friends_count": 13661,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 84613584,
#         "id_str": "84613584",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 10402,
#         "location": "M\u00e9xico",
#         "name": "AnimalPolitico.com",
#         "notifications": false,
#         "profile_background_color": "EDECE9",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme3/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme3/bg.gif",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/84613584/1552880830",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1065959279381770240/OtG73Ket_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1065959279381770240/OtG73Ket_normal.jpg",
#         "profile_link_color": "088253",
#         "profile_sidebar_border_color": "D3D2CF",
#         "profile_sidebar_fill_color": "E3E2DE",
#         "profile_text_color": "634047",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Pajaropolitico",
#         "statuses_count": 564977,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/6FkluWidsv",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:10:22 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "nytimes.com/2019/03/30/opi\u2026",
#                 "expanded_url": "https://www.nytimes.com/2019/03/30/opinion/the-incredible-shrinking-trump-boom.html",
#                 "indices": [
#                     115,
#                     138
#                 ],
#                 "url": "https://t.co/7vWPYiOA7e"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 62,
#     "favorited": false,
#     "geo": null,
#     "id": 1112039375976742915,
#     "id_str": "1112039375976742915",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 25,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "text": "While we debate the merits of Stephen Moore -- bad, really bad, or absolutely awful? -- some notes on Trumponomics https://t.co/7vWPYiOA7e",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Mon Oct 27 20:17:02 +0000 2008",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Nobel laureate. Op-Ed columnist, @nytopinion. Author, \u201cThe Return of Depression Economics,\u201d \u201cThe Great Unraveling,\u201d \u201cThe Age of Diminished Expectations\u201d + more.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "nytimes.com/column/paul-kr\u2026",
#                         "expanded_url": "https://www.nytimes.com/column/paul-krugman",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/eyXDbYebpR"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 29,
#         "follow_request_sent": false,
#         "followers_count": 4525441,
#         "following": true,
#         "friends_count": 43,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 17006157,
#         "id_str": "17006157",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 36761,
#         "location": "New York City",
#         "name": "Paul Krugman",
#         "notifications": false,
#         "profile_background_color": "9AE4E8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/2044852218/NYT_Twitter_Krugman_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/2044852218/NYT_Twitter_Krugman_normal.png",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "BDDCAD",
#         "profile_sidebar_fill_color": "DDFFCC",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "paulkrugman",
#         "statuses_count": 14785,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/eyXDbYebpR",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:09:07 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "sopitas.com/deportes/5-equ\u2026",
#                 "expanded_url": "https://www.sopitas.com/deportes/5-equipos-pelean-septimo-lugar-premier-league-ronda-previa-europa-league/",
#                 "indices": [
#                     66,
#                     89
#                 ],
#                 "url": "https://t.co/4bobOlYJ5L"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 7,
#     "favorited": false,
#     "geo": null,
#     "id": 1112039061018066944,
#     "id_str": "1112039061018066944",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "es",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 2,
#     "retweeted": false,
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text": "De ganar, 'Chicharito' podr\u00eda aguarle la fiesta a Ra\u00fal Jim\u00e9nez \ud83d\ude2e\n\nhttps://t.co/4bobOlYJ5L",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Apr 03 21:18:19 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Un tipo muy afortunado!\n\nContacto: sopitas@sopitas.com",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "sopitas.com",
#                         "expanded_url": "http://www.sopitas.com",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/jomeE6HI0O"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 2973,
#         "follow_request_sent": false,
#         "followers_count": 3005662,
#         "following": true,
#         "friends_count": 3184,
#         "geo_enabled": true,
#         "has_extended_profile": true,
#         "id": 3362741,
#         "id_str": "3362741",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 6622,
#         "location": "Mexico",
#         "name": "Sopitas",
#         "notifications": false,
#         "profile_background_color": "9AE4E8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/3362741/1543075790",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1066360955917881344/1JEzA5He_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1066360955917881344/1JEzA5He_normal.jpg",
#         "profile_link_color": "0000FF",
#         "profile_sidebar_border_color": "87BC44",
#         "profile_sidebar_fill_color": "E0FF92",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "sopitas",
#         "statuses_count": 165469,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://t.co/jomeE6HI0O",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:08:48 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1112038982727204864",
#                 "indices": [
#                     96,
#                     119
#                 ],
#                 "url": "https://t.co/wo6h7iJGHW"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 7,
#     "favorited": false,
#     "geo": null,
#     "id": 1112038982727204864,
#     "id_str": "1112038982727204864",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "es",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://www.hootsuite.com\" rel=\"nofollow\">Hootsuite Inc.</a>",
#     "text": "El cambio del r\u00e9gimen pol\u00edtico y la revocaci\u00f3n de mandato |Art\u00edculo de Rogelio Mu\u00f1iz Toledo  \ud83d\udc47\u2026 https://t.co/wo6h7iJGHW",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sat Mar 10 19:08:28 +0000 2012",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Esta cuenta es administrada por Carmen Aristegui y el equipo de Aristegui Noticias. Los tuits de Carmen se firmar\u00e1n como \u201c-C. Aristegui\u201d o \u201c-C.\u201d.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "AristeguiNoticias.com",
#                         "expanded_url": "http://AristeguiNoticias.com",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/yuBuzoDMxo"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 83,
#         "follow_request_sent": false,
#         "followers_count": 8250700,
#         "following": true,
#         "friends_count": 8,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 520653311,
#         "id_str": "520653311",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 14342,
#         "location": "M\u00e9xico, DF",
#         "name": "Aristegui Noticias",
#         "notifications": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/520653311/1549057415",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1067110021115170816/YAPVlY0W_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1067110021115170816/YAPVlY0W_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "AristeguiOnline",
#         "statuses_count": 250449,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://t.co/yuBuzoDMxo",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:01:02 +0000 2019",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     36,
#                     41
#                 ],
#                 "text": "CDMX"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1112037027594321921",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/Xfb2X6WkmH"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 3,
#     "favorited": false,
#     "geo": null,
#     "id": 1112037027594321921,
#     "id_str": "1112037027594321921",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "es",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 3,
#     "retweeted": false,
#     "source": "<a href=\"https://buffer.com\" rel=\"nofollow\">Buffer</a>",
#     "text": "Y en lugares ricos para comer en la #CDMX, este fin de semana tocan recomendaciones en la San Miguel Chapultepec. \ud83d\ude0b\u2026 https://t.co/Xfb2X6WkmH",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Oct 23 15:13:11 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Periodismo independiente con todo el rigor. El sitio de noticias de M\u00e9xico es Animal Pol\u00edtico.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "AnimalPolitico.com",
#                         "expanded_url": "http://AnimalPolitico.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/6FkluWidsv"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 19698,
#         "follow_request_sent": false,
#         "followers_count": 2000062,
#         "following": true,
#         "friends_count": 13661,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 84613584,
#         "id_str": "84613584",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 10402,
#         "location": "M\u00e9xico",
#         "name": "AnimalPolitico.com",
#         "notifications": false,
#         "profile_background_color": "EDECE9",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme3/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme3/bg.gif",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/84613584/1552880830",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1065959279381770240/OtG73Ket_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1065959279381770240/OtG73Ket_normal.jpg",
#         "profile_link_color": "088253",
#         "profile_sidebar_border_color": "D3D2CF",
#         "profile_sidebar_fill_color": "E3E2DE",
#         "profile_text_color": "634047",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Pajaropolitico",
#         "statuses_count": 564977,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/6FkluWidsv",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:00:04 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1112036784190439424",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/zirDPO2GZz"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 35,
#     "favorited": false,
#     "geo": null,
#     "id": 1112036784190439424,
#     "id_str": "1112036784190439424",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 23,
#     "retweeted": false,
#     "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#     "text": "The Border Patrol has been facing a record influx of migrant families since fall, but in recent weeks the numbers h\u2026 https://t.co/zirDPO2GZz",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Mar 02 20:41:42 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "nyti.ms/2FVHq9v",
#                         "expanded_url": "http://nyti.ms/2FVHq9v",
#                         "indices": [
#                             113,
#                             136
#                         ],
#                         "url": "https://t.co/ghL9OoYKMM"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "nytimes.com",
#                         "expanded_url": "http://www.nytimes.com/",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/ahvuWqicF9"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 17737,
#         "follow_request_sent": false,
#         "followers_count": 43133221,
#         "following": true,
#         "friends_count": 887,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 807095,
#         "id_str": "807095",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 199623,
#         "location": "New York City",
#         "name": "The New York Times",
#         "notifications": false,
#         "profile_background_color": "131516",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/807095/1522172276",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png",
#         "profile_link_color": "607696",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "nytimes",
#         "statuses_count": 354457,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://t.co/ahvuWqicF9",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:00:03 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1112036777882058752",
#                 "indices": [
#                     107,
#                     130
#                 ],
#                 "url": "https://t.co/vD5A6vPU15"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1112036777882058752,
#     "id_str": "1112036777882058752",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "es",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 1,
#     "retweeted": false,
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text": "Transmitiendo desde Jukapo, Ciudad Capital con 2100 watts de potencia radiada obtenida con energ\u00eda solar.\u2026 https://t.co/vD5A6vPU15",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sat Mar 07 19:20:35 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "La radio se contagia | Proyecto radiof\u00f3nico y digital de la @ibero_mx Tel\u00e9fono en cabina: 52 92 5909",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "ibero909.fm",
#                         "expanded_url": "http://ibero909.fm",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/Q3REU0IjLv"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 5030,
#         "follow_request_sent": false,
#         "followers_count": 587710,
#         "following": true,
#         "friends_count": 868,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 23224159,
#         "id_str": "23224159",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 2546,
#         "location": "Mexico City",
#         "name": "Ibero 90.9 FM",
#         "notifications": false,
#         "profile_background_color": "131516",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/23224159/1551986763",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1102739959117742080/NmqdtRRA_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1102739959117742080/NmqdtRRA_normal.png",
#         "profile_link_color": "3434E3",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Ibero909FM",
#         "statuses_count": 65396,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/Q3REU0IjLv",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 17:00:00 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1112036767941591041",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/VURumo4odm"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1112036767941591041,
#     "id_str": "1112036767941591041",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "es",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text": "\"Las dos Cassandras\" retrata c\u00f3mo Cassandra, de 30 a\u00f1os, intenta escribir un discurso f\u00fanebre tras la repentina mue\u2026 https://t.co/VURumo4odm",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sat Mar 07 19:20:35 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "La radio se contagia | Proyecto radiof\u00f3nico y digital de la @ibero_mx Tel\u00e9fono en cabina: 52 92 5909",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "ibero909.fm",
#                         "expanded_url": "http://ibero909.fm",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/Q3REU0IjLv"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 5030,
#         "follow_request_sent": false,
#         "followers_count": 587710,
#         "following": true,
#         "friends_count": 868,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 23224159,
#         "id_str": "23224159",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 2546,
#         "location": "Mexico City",
#         "name": "Ibero 90.9 FM",
#         "notifications": false,
#         "profile_background_color": "131516",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/23224159/1551986763",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1102739959117742080/NmqdtRRA_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1102739959117742080/NmqdtRRA_normal.png",
#         "profile_link_color": "3434E3",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "Ibero909FM",
#         "statuses_count": 65396,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/Q3REU0IjLv",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 16:55:36 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/KBuZRfFYi0",
#                 "expanded_url": "https://twitter.com/RoyCampos/status/1112035657835147265/photo/1",
#                 "id": 1112035654882357248,
#                 "id_str": "1112035654882357248",
#                 "indices": [
#                     0,
#                     23
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/D26-iUrU8AAg7g_.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/D26-iUrU8AAg7g_.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 468,
#                         "resize": "fit",
#                         "w": 841
#                     },
#                     "medium": {
#                         "h": 468,
#                         "resize": "fit",
#                         "w": 841
#                     },
#                     "small": {
#                         "h": 378,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/KBuZRfFYi0"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/KBuZRfFYi0",
#                 "expanded_url": "https://twitter.com/RoyCampos/status/1112035657835147265/photo/1",
#                 "id": 1112035654882357248,
#                 "id_str": "1112035654882357248",
#                 "indices": [
#                     0,
#                     23
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/D26-iUrU8AAg7g_.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/D26-iUrU8AAg7g_.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 468,
#                         "resize": "fit",
#                         "w": 841
#                     },
#                     "medium": {
#                         "h": 468,
#                         "resize": "fit",
#                         "w": 841
#                     },
#                     "small": {
#                         "h": 378,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/KBuZRfFYi0"
#             }
#         ]
#     },
#     "favorite_count": 42,
#     "favorited": false,
#     "geo": null,
#     "id": 1112035657835147265,
#     "id_str": "1112035657835147265",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "und",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 12,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "https://t.co/KBuZRfFYi0",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun Aug 23 01:24:12 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Platico de pol\u00edtica, de deportes, disfruto buenos chistes y creo mucho en M\u00e9xico. visiten http://t.co/aVhVNYvv1k @mitofsky_group",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "consulta.mx",
#                         "expanded_url": "http://www.consulta.mx",
#                         "indices": [
#                             90,
#                             112
#                         ],
#                         "url": "http://t.co/aVhVNYvv1k"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "consulta.mx",
#                         "expanded_url": "http://www.consulta.mx",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/aVhVNYerZk"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 934,
#         "follow_request_sent": false,
#         "followers_count": 1147208,
#         "following": true,
#         "friends_count": 721543,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 68036460,
#         "id_str": "68036460",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 5743,
#         "location": "M\u00e9xico City",
#         "name": "Roy Campos",
#         "notifications": false,
#         "profile_background_color": "080808",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/68036460/1482800662",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1099288255260962817/BOlEAYxw_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1099288255260962817/BOlEAYxw_normal.jpg",
#         "profile_link_color": "981CEB",
#         "profile_sidebar_border_color": "ED0E1D",
#         "profile_sidebar_fill_color": "A1A132",
#         "profile_text_color": "080808",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "RoyCampos",
#         "statuses_count": 166190,
#         "time_zone": null,
#         "translator_type": "regular",
#         "url": "http://t.co/aVhVNYerZk",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 16:50:57 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/xertIyhtDA",
#                 "expanded_url": "https://twitter.com/RoyCampos/status/1112034489675333632/photo/1",
#                 "id": 1112034483128012800,
#                 "id_str": "1112034483128012800",
#                 "indices": [
#                     0,
#                     23
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/D269eHjUkAAhbLb.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/D269eHjUkAAhbLb.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1280,
#                         "resize": "fit",
#                         "w": 905
#                     },
#                     "medium": {
#                         "h": 1200,
#                         "resize": "fit",
#                         "w": 848
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 481
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/xertIyhtDA"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/xertIyhtDA",
#                 "expanded_url": "https://twitter.com/RoyCampos/status/1112034489675333632/photo/1",
#                 "id": 1112034483128012800,
#                 "id_str": "1112034483128012800",
#                 "indices": [
#                     0,
#                     23
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/D269eHjUkAAhbLb.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/D269eHjUkAAhbLb.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 1280,
#                         "resize": "fit",
#                         "w": 905
#                     },
#                     "medium": {
#                         "h": 1200,
#                         "resize": "fit",
#                         "w": 848
#                     },
#                     "small": {
#                         "h": 680,
#                         "resize": "fit",
#                         "w": 481
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/xertIyhtDA"
#             }
#         ]
#     },
#     "favorite_count": 92,
#     "favorited": false,
#     "geo": null,
#     "id": 1112034489675333632,
#     "id_str": "1112034489675333632",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "und",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 54,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "text": "https://t.co/xertIyhtDA",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun Aug 23 01:24:12 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Platico de pol\u00edtica, de deportes, disfruto buenos chistes y creo mucho en M\u00e9xico. visiten http://t.co/aVhVNYvv1k @mitofsky_group",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "consulta.mx",
#                         "expanded_url": "http://www.consulta.mx",
#                         "indices": [
#                             90,
#                             112
#                         ],
#                         "url": "http://t.co/aVhVNYvv1k"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "consulta.mx",
#                         "expanded_url": "http://www.consulta.mx",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/aVhVNYerZk"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 934,
#         "follow_request_sent": false,
#         "followers_count": 1147208,
#         "following": true,
#         "friends_count": 721543,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 68036460,
#         "id_str": "68036460",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 5743,
#         "location": "M\u00e9xico City",
#         "name": "Roy Campos",
#         "notifications": false,
#         "profile_background_color": "080808",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/68036460/1482800662",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1099288255260962817/BOlEAYxw_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1099288255260962817/BOlEAYxw_normal.jpg",
#         "profile_link_color": "981CEB",
#         "profile_sidebar_border_color": "ED0E1D",
#         "profile_sidebar_fill_color": "A1A132",
#         "profile_text_color": "080808",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "RoyCampos",
#         "statuses_count": 166190,
#         "time_zone": null,
#         "translator_type": "regular",
#         "url": "http://t.co/aVhVNYerZk",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 16:49:20 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/0esrA99iQU",
#                 "expanded_url": "https://twitter.com/RoyCampos/status/1112034082173546496/photo/1",
#                 "id": 1112034079828918272,
#                 "id_str": "1112034079828918272",
#                 "indices": [
#                     0,
#                     23
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/D269GpJUwAARt4f.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/D269GpJUwAARt4f.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 661,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "medium": {
#                         "h": 661,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "small": {
#                         "h": 661,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/0esrA99iQU"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/0esrA99iQU",
#                 "expanded_url": "https://twitter.com/RoyCampos/status/1112034082173546496/photo/1",
#                 "id": 1112034079828918272,
#                 "id_str": "1112034079828918272",
#                 "indices": [
#                     0,
#                     23
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/D269GpJUwAARt4f.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/D269GpJUwAARt4f.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 661,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "medium": {
#                         "h": 661,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "small": {
#                         "h": 661,
#                         "resize": "fit",
#                         "w": 640
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/0esrA99iQU"
#             }
#         ]
#     },
#     "favorite_count": 49,
#     "favorited": false,
#     "geo": null,
#     "id": 1112034082173546496,
#     "id_str": "1112034082173546496",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "und",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 11,
#     "retweeted": false,
# ...
#         "id": 520653311,
#         "id_str": "520653311",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 14342,
#         "location": "M\u00e9xico, DF",
#         "name": "Aristegui Noticias",
#         "notifications": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/520653311/1549057415",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1067110021115170816/YAPVlY0W_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1067110021115170816/YAPVlY0W_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "AristeguiOnline",
#         "statuses_count": 250449,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://t.co/yuBuzoDMxo",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sat Mar 30 14:15:07 +0000 2019",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1111995271406370817",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/CWT0rXVufU"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 134,
#     "favorited": false,
#     "geo": null,
#     "id": 1111995271406370817,
#     "id_str": "1111995271406370817",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 55,
#     "retweeted": false,
#     "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#     "text": "Publicly, 2020 Democratic presidential candidates are focused on attracting small donors to prove grass-roots appea\u2026 https://t.co/CWT0rXVufU",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Mar 02 20:41:42 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "Where the conversation begins. Follow for breaking news, special reports, RTs of our journalists and more. Visit https://t.co/ghL9OoYKMM to share news tips.",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "nyti.ms/2FVHq9v",
#                         "expanded_url": "http://nyti.ms/2FVHq9v",
#                         "indices": [
#                             113,
#                             136
#                         ],
#                         "url": "https://t.co/ghL9OoYKMM"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "nytimes.com",
#                         "expanded_url": "http://www.nytimes.com/",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/ahvuWqicF9"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 17737,
#         "follow_request_sent": false,
#         "followers_count": 43133221,
#         "following": true,
#         "friends_count": 887,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 807095,
#         "id_str": "807095",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 199623,
#         "location": "New York City",
#         "name": "The New York Times",
#         "notifications": false,
#         "profile_background_color": "131516",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/807095/1522172276",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png",
#         "profile_link_color": "607696",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "nytimes",
#         "statuses_count": 354457,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://t.co/ahvuWqicF9",
#         "utc_offset": null,
#         "verified": true
#     }
# }
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in _read_status(self)
#     264             # sending a valid response.
# --> 265             raise RemoteDisconnected("Remote end closed connection without"
#     266                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in _read_status(self)
#     264             # sending a valid response.
# --> 265             raise RemoteDisconnected("Remote end closed connection without"
#     266                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\binder.py in execute(self)
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-6-fd02bdae9bf7> in <module>
# ----> 1 for status in tweepy.Cursor(api.home_timeline).items(200):
#       2     print(json.dumps(status._json,indent=4,sort_keys=True))
#       3
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~\AppData\Roaming\Python\Python37\site-packages\six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# TweepError: Failed to send request: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
class StreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
stream.filter(track=["asalto"],languages=["es"])
print(stream)
# Out:
# @RosaMar6254 UP/PSOE: Sois "Another Brick in the Wall"
# Si ya  UP se bajó PANTALONES ante un triste PSOE admitiendo… https://t.co/548pzWbFTP
# LA INSEGURIDAD EN PIEL VIVA https://t.co/FZchQEdtRm
# Les juro que un perro acaba de salvarme de un asalto 😩😩😩
# RT @lupitodrn: -no te preocupes we, ya le hablamos a la policia pa que agarren al wey que te asalto
#
# -la policia: https://t.co/vjU8QKtAiq
# RT @GustavoVela71: Asalto con chile de árbol ⁦@trinomonero⁩ https://t.co/7isUSHc7WI
# RT @Ejercito_Arg: #BuenosAires En el marco del Curso de Asalto Aéreo, la Agrupación de Aviación de Ejército 601 dio apoyo a la Escuela de T…
# RT @Contexto_Tuc: Video: feroz asalto de motochorros a un productor de papas frente al Mercofrut https://t.co/YS81LdIkRQ
# RT @lupitodrn: -no te preocupes we, ya le hablamos a la policia pa que agarren al wey que te asalto
#
# -la policia: https://t.co/vjU8QKtAiq
# RT @lupitodrn: -no te preocupes we, ya le hablamos a la policia pa que agarren al wey que te asalto
#
# -la policia: https://t.co/vjU8QKtAiq
# RT @lupitodrn: -no te preocupes we, ya le hablamos a la policia pa que agarren al wey que te asalto
#
# -la policia: https://t.co/vjU8QKtAiq
# En media hora os esperamos en la Jornada cultural del grupo Asalto.¡No podéis faltar!
# https://t.co/GPq3F4EZFR https://t.co/GPq3F4EZFR
# RT @marioeagle: Yo no veo ninguna lucha contra la corrupción. Veo un asalto de un grupo corrupto -con agenda propia- para tomar el poder. E…
# RT @ForosTelecinco: @Irene_Montero_ @iunida @ahorapodemos La agresión del Planeta por el asalto de la #geoingeniería  es testimonio de la p…
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-dfed8b35badf> in <module>
#      10 stream_listener = StreamListener()
#      11 stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
# ---> 12 stream.filter(track=["asalto"],languages=["es"])
#      13 print(stream)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# ~\Anaconda3\envs\pythonrules\lib\http\client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# ~\Anaconda3\envs\pythonrules\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      81     # thing.)
#      82     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 83     rready, wready, xready = _retry_on_intr(fn, timeout)
#      84     return bool(rready or wready or xready)
#      85
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# KeyboardInterrupt:
