# %%
try:
    import json
except ImportError:
    import simplejson as json

# Import the tweepy library
import twitter
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

from pandas import Series

# %%
# Variables that contains the user credentials to access Twitter API 

api = twitter.Api(consumer_key='OcfcqAZGIvtUKWCEO9XfWhCjW',
                      consumer_secret='jnFRZ0daR2xdzy7IEjR6ih98ej44UO2ioEkZg95INwtefXyLJU',
                      access_token_key='54224760-OHpN11y0XuEoycqVaeXj3Bo4m7wFDKoWsAxuNDAdH',
                      access_token_secret='p4iai7fWiuR3o2gCdzPMEgXkjW4e6wbv7I1MQQKbQ6gzn')
# Setup tweepy to authenticate with Twitter credentials

# %%
#results = api.GetSearch(
#    raw_query="q=asalto%20since%3A2019-03-06&src=typd&lang=es")
results = api.GetSearch(
   term="#ultra2019", count=200, lang="en", return_json=True,until="2019-03-31"
   #term="nfl", geocode="19.4326,-99.1332,200mi", since="2019-01-01",count=50, lang="es", return_json=True
   )
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\envs\pythonrules\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000001F57B92E6A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?until=2019-03-31&lang=en&q=%23ultra2019&count=200&result_type=mixed&tweet_mode=compat (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001F57B92E6A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-98992592ed47> in <module>
#       2 #    raw_query="q=asalto%20since%3A2019-03-06&src=typd&lang=es")
#       3 results = api.GetSearch(
# ----> 4    term="#ultra2019", count=200, lang="en", return_json=True,until="2019-03-31"
#       5    #term="nfl", geocode="19.4326,-99.1332,200mi", since="2019-01-01",count=50, lang="es", return_json=True
#       6    )
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\twitter\api.py in GetSearch(self, term, raw_query, geocode, since_id, max_id, until, since, count, lang, locale, result_type, include_entities, return_json)
#     526             resp = self._RequestUrl(url, 'GET')
#     527         else:
# --> 528             resp = self._RequestUrl(url, 'GET', data=parameters)
#     529
#     530         data = self._ParseAndCheckTwitter(resp.content.decode('utf-8'))
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\twitter\api.py in _RequestUrl(self, url, verb, data, json, enforce_auth)
#    4990             data['tweet_mode'] = self.tweet_mode
#    4991             url = self._BuildUrl(url, extra_params=data)
# -> 4992             resp = self._session.get(url, auth=self.__auth, timeout=self._timeout, proxies=self.proxies)
#    4993
#    4994         else:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?until=2019-03-31&lang=en&q=%23ultra2019&count=200&result_type=mixed&tweet_mode=compat (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001F57B92E6A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
print(len(results['statuses']))
# Out:
# 100

# %%
print(json.dumps(results,indent=4))
# Out:
# {
#     "statuses": [
#         {
#             "created_at": "Wed Mar 27 16:23:20 +0000 2019",
#             "id": 1110940375609475072,
#             "id_str": "1110940375609475072",
#             "text": "MIAMI, ARE YOU READY?\n\nOnly 2 more days until #Ultra2019 https://t.co/NBGoNmTzwO",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Ultra2019",
#                         "indices": [
#                             46,
#                             56
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1110939659557892096,
#                         "id_str": "1110939659557892096",
#                         "indices": [
#                             57,
#                             80
#                         ],
#                         "media_url": "http://pbs.twimg.com/amplify_video_thumb/1110939659557892096/img/uE0ziSS5ROeiFLZI.jpg",
#                         "media_url_https": "https://pbs.twimg.com/amplify_video_thumb/1110939659557892096/img/uE0ziSS5ROeiFLZI.jpg",
#                         "url": "https://t.co/NBGoNmTzwO",
#                         "display_url": "pic.twitter.com/NBGoNmTzwO",
#                         "expanded_url": "https://twitter.com/ultra/status/1110940375609475072/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 544,
#                                 "h": 680,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 960,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1024,
#                                 "h": 1280,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1110939659557892096,
#                         "id_str": "1110939659557892096",
#                         "indices": [
#                             57,
#                             80
#                         ],
#                         "media_url": "http://pbs.twimg.com/amplify_video_thumb/1110939659557892096/img/uE0ziSS5ROeiFLZI.jpg",
#                         "media_url_https": "https://pbs.twimg.com/amplify_video_thumb/1110939659557892096/img/uE0ziSS5ROeiFLZI.jpg",
#                         "url": "https://t.co/NBGoNmTzwO",
#                         "display_url": "pic.twitter.com/NBGoNmTzwO",
#                         "expanded_url": "https://twitter.com/ultra/status/1110940375609475072/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 544,
#                                 "h": 680,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 960,
#                                 "h": 1200,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1024,
#                                 "h": 1280,
#                                 "resize": "fit"
#                             }
#                         },
#                         "video_info": {
#                             "aspect_ratio": [
#                                 4,
#                                 5
#                             ],
#                             "duration_millis": 15000,
#                             "variants": [
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/amplify_video/1110939659557892096/vid/720x900/bqYuJsBnw_z1TaKW.mp4?tag=11"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/amplify_video/1110939659557892096/pl/WnVtIv6M6186qW9t.m3u8?tag=11"
#                                 },
#                                 {
#                                     "bitrate": 632000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/amplify_video/1110939659557892096/vid/320x400/TBldKg8SsKNlKtn2.mp4?tag=11"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/amplify_video/1110939659557892096/vid/360x450/k58rSLdXaXn6gx9z.mp4?tag=11"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "title": "2 MORE DAYS UNTIL #Ultra2019!",
#                             "description": "",
#                             "call_to_actions": {
#                                 "visit_site": {
#                                     "url": "https://ultramusicfestival.com"
#                                 }
#                             },
#                             "embeddable": true,
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "result_type": "popular",
#                 "iso_language_code": "en"
#             },
#             "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 22838300,
#                 "id_str": "22838300",
#                 "name": "Ultra Music Festival",
#                 "screen_name": "ultra",
#                 "location": "Miami, FL",
#                 "description": "The only OFFICIAL twitter account for ULTRA MUSIC FESTIVAL \u2013 the world\u2019s premier electronic music festival",
#                 "url": "https://t.co/P7YfQDVake",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/P7YfQDVake",
#                                 "expanded_url": "http://www.ultramusicfestival.com",
#                                 "display_url": "ultramusicfestival.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2199683,
#                 "friends_count": 65,
#                 "listed_count": 3945,
#                 "created_at": "Wed Mar 04 21:34:22 +0000 2009",
#                 "favourites_count": 2047,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": true,
#                 "statuses_count": 10766,
#                 "lang": "en",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": true,
#                 "profile_background_color": "000003",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme6/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme6/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1076013069053116418/QoZIDC2Q_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1076013069053116418/QoZIDC2Q_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/22838300/1554394232",
#                 "profile_link_color": "61ABFF",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "C2C2C2",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 1016,
#             "favorite_count": 4135,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sat Mar 30 02:22:59 +0000 2019",
#             "id": 1111816056924966912,
#             "id_str": "1111816056924966912",
#             "text": "WE COULD BE HEROES\n\n#Ultra2019",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Ultra2019",
#                         "indices": [
#                             20,
#                             30
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "result_type": "popular",
#                 "iso_language_code": "en"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 22838300,
#                 "id_str": "22838300",
#                 "name": "Ultra Music Festival",
#                 "screen_name": "ultra",
#                 "location": "Miami, FL",
#                 "description": "The only OFFICIAL twitter account for ULTRA MUSIC FESTIVAL \u2013 the world\u2019s premier electronic music festival",
#                 "url": "https://t.co/P7YfQDVake",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/P7YfQDVake",
#                                 "expanded_url": "http://www.ultramusicfestival.com",
#                                 "display_url": "ultramusicfestival.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2199683,
#                 "friends_count": 65,
#                 "listed_count": 3945,
#                 "created_at": "Wed Mar 04 21:34:22 +0000 2009",
#                 "favourites_count": 2047,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": true,
#                 "statuses_count": 10766,
#                 "lang": "en",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": true,
#                 "profile_background_color": "000003",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme6/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme6/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1076013069053116418/QoZIDC2Q_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1076013069053116418/QoZIDC2Q_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/22838300/1554394232",
#                 "profile_link_color": "61ABFF",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "C2C2C2",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 818,
#             "favorite_count": 3968,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sat Mar 30 13:49:00 +0000 2019",
#             "id": 1111988698961182730,
#             "id_str": "1111988698961182730",
#             "text": "Are you ready for #Ultra2019?\ud83d\ude4c Get in the mood and relive my @Ultra sets on my YouTube channel!\nWatch here \u27a1\ufe0f\u2026 https://t.co/gxT65JfKiD",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Ultra2019",
#                         "indices": [
#                             18,
#                             28
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "ultra",
#                         "name": "Ultra Music Festival",
#                         "id": 22838300,
#                         "id_str": "22838300",
#                         "indices": [
#                             61,
#                             67
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/gxT65JfKiD",
#                         "expanded_url": "https://twitter.com/i/web/status/1111988698961182730",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             111,
#                             134
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "result_type": "popular",
#                 "iso_language_code": "en"
#             },
#             "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 21787625,
#                 "id_str": "21787625",
#                 "name": "Hardwell",
#                 "screen_name": "HARDWELL",
#                 "location": "",
#                 "description": "DJ/Producer | Labels: @RevealedRec @Gemstonerec \ud83d\udc8e | Radioshow: @HardwellOnAir | Merch:https://t.co/znt5TN4cyW",
#                 "url": "https://t.co/D7gH2V6cEj",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/D7gH2V6cEj",
#                                 "expanded_url": "http://www.djhardwell.com",
#                                 "display_url": "djhardwell.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/znt5TN4cyW",
#                                 "expanded_url": "http://hardwellshop.com",
#                                 "display_url": "hardwellshop.com",
#                                 "indices": [
#                                     86,
#                                     109
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 7759836,
#                 "friends_count": 1053,
#                 "listed_count": 5283,
#                 "created_at": "Tue Feb 24 19:38:00 +0000 2009",
#                 "favourites_count": 7236,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": true,
#                 "statuses_count": 11784,
#                 "lang": "nl",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": true,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#                 "profile_background_tile": true,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/969590024927940609/NoLH3Ek0_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/969590024927940609/NoLH3Ek0_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/21787625/1552399809",
#                 "profile_link_color": "7D9093",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "0F0F0F",
#                 "profile_text_color": "757575",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "regular"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 418,
#             "favorite_count": 1860,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sat Mar 30 23:59:58 +0000 2019",
#             "id": 1112142455955251200,
#             "id_str": "1112142455955251200",
#             "text": "RT @lllucia_: PARDON MY FRENCH IN THE HOUSE. @iamTchami \ud83d\ude4f\ud83d\udd25 #Ultra2019 #ULTRALIVE",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Ultra2019",
#                         "indices": [
#                             59,
#                             69
#                         ]
#                     },
#                     {
#                         "text": "ULTRALIVE",
#                         "indices": [
#                             70,
#                             80
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "lllucia_",
#                         "name": "Mariana.",
#                         "id": 1716915108,
#                         "id_str": "1716915108",
#                         "indices": [
#                             3,
#                             12
#                         ]
#                     },
#                     {
#                         "screen_name": "iamTchami",
#                         "name": "TCHAMI",
#                         "id": 1152748446,
#                         "id_str": "1152748446",
#                         "indices": [
#                             45,
#                             55
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 859597306953441283,
#                 "id_str": "859597306953441283",
#                 "name": "Marco Jimenes",
#                 "screen_name": "marcks5678",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 0,
#                 "friends_count": 26,
#                 "listed_count": 0,
#                 "created_at": "Wed May 03 02:35:43 +0000 2017",
#                 "favourites_count": 3309,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 3269,
#                 "lang": "es",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": true,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Sat Mar 30 23:47:41 +0000 2019",
#                 "id": 1112139364140752897,
#                 "id_str": "1112139364140752897",
#                 "text": "PARDON MY FRENCH IN THE HOUSE. @iamTchami \ud83d\ude4f\ud83d\udd25 #Ultra2019 #ULTRALIVE",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Ultra2019",
#                             "indices": [
#                                 45,
#                                 55
#                             ]
#                         },
#                         {
#                             "text": "ULTRALIVE",
#                             "indices": [
#                                 56,
#                                 66
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [
#                         {
#                             "screen_name": "iamTchami",
#                             "name": "TCHAMI",
#                             "id": 1152748446,
#                             "id_str": "1152748446",
#                             "indices": [
#                                 31,
#                                 41
#                             ]
#                         }
#                     ],
#                     "urls": []
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1716915108,
#                     "id_str": "1716915108",
#                     "name": "Mariana.",
#                     "screen_name": "lllucia_",
#                     "location": "",
#                     "description": "Music is my escape.\u2764\ufe0f",
#                     "url": "https://t.co/Rsd9wjE7Mp",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/Rsd9wjE7Mp",
#                                     "expanded_url": "https://www.facebook.com/mariana.asteguieta21",
#                                     "display_url": "facebook.com/mariana.astegu\u2026",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2317,
#                     "friends_count": 884,
#                     "listed_count": 44,
#                     "created_at": "Sat Aug 31 22:18:07 +0000 2013",
#                     "favourites_count": 46786,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": false,
#                     "statuses_count": 51368,
#                     "lang": "es",
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "642D8B",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme10/bg.gif",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme10/bg.gif",
#                     "profile_background_tile": true,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1112514117640880134/lF6uNn0-_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1112514117640880134/lF6uNn0-_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1716915108/1554078235",
#                     "profile_link_color": "FF691F",
#                     "profile_sidebar_border_color": "FFFFFF",
#                     "profile_sidebar_fill_color": "7AC3EE",
#                     "profile_text_color": "3D1957",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "regular"
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 8,
#                 "favorite_count": 9,
#                 "favorited": false,
#                 "retweeted": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 8,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sat Mar 30 23:59:57 +0000 2019",
#             "id": 1112142451379261441,
#             "id_str": "1112142451379261441",
#             "text": "FATHER OF HOUSEEE #Ultra2019",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Ultra2019",
#                         "indices": [
#                             18,
#                             28
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 2167192151,
#                 "id_str": "2167192151",
#                 "name": "MARIA LAGUNA \u25cfULTRA\u25cf \u2661CREA4TIVE",
#                 "screen_name": "marialagunaaa",
#                 "location": "",
#                 "description": "\u26a1\ud83d\udd0a\ud83c\udfa7\n\ud83e\udd8b\ud83d\udd2e\ud83c\udf19",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 288,
#                 "friends_count": 1039,
#                 "listed_count": 7,
#                 "created_at": "Mon Nov 04 00:31:30 +0000 2013",
#                 "favourites_count": 11204,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 8772,
#                 "lang": "es",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "59472F",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1111608772479340544/-rL20-zl_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1111608772479340544/-rL20-zl_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2167192151/1554244858",
#                 "profile_link_color": "981CEB",
#                 "profile_sidebar_border_color": "000515",
#                 "profile_sidebar_fill_color": "0A2457",
#                 "profile_text_color": "827972",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 1,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sat Mar 30 23:59:55 +0000 2019",
#             "id": 1112142441451266050,
#             "id_str": "1112142441451266050",
#             "text": "RT @RafaaFreitass: LOOK AT THIS VIEW \n\n#ULTRA2019 https://t.co/W7krqUijGV",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "ULTRA2019",
#                         "indices": [
#                             39,
#                             49
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "RafaaFreitass",
#                         "name": "Rafael Freitas",
#                         "id": 55288283,
#                         "id_str": "55288283",
#                         "indices": [
#                             3,
#                             17
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1112142341094154240,
#                         "id_str": "1112142341094154240",
#                         "indices": [
#                             50,
#                             73
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                         "url": "https://t.co/W7krqUijGV",
#                         "display_url": "pic.twitter.com/W7krqUijGV",
#                         "expanded_url": "https://twitter.com/RafaaFreitass/status/1112142390444335105/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 1366,
#                                 "h": 768,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 382,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1112142390444335105,
#                         "source_status_id_str": "1112142390444335105",
#                         "source_user_id": 55288283,
#                         "source_user_id_str": "55288283"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1112142341094154240,
#                         "id_str": "1112142341094154240",
#                         "indices": [
#                             50,
#                             73
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                         "url": "https://t.co/W7krqUijGV",
#                         "display_url": "pic.twitter.com/W7krqUijGV",
#                         "expanded_url": "https://twitter.com/RafaaFreitass/status/1112142390444335105/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 1366,
#                                 "h": 768,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 382,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1112142390444335105,
#                         "source_status_id_str": "1112142390444335105",
#                         "source_user_id": 55288283,
#                         "source_user_id_str": "55288283"
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1656444234,
#                 "id_str": "1656444234",
#                 "name": "\u25e2\u25e4Manuel Aquino Lay \u25e2\u25e4",
#                 "screen_name": "manuelaquino03",
#                 "location": "Santo Domingo Dominican Rep.",
#                 "description": "Estudiante de Ingenier\u00eda Electr\u00f3nica, y Amante la M\u00fasica Electr\u00f3nica en especial el Hardstyle, Trance, EDM Big Room y Progressive House\nInstagram: Manuel_AL003",
#                 "url": "https://t.co/ZBvZ3XoIuu",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/ZBvZ3XoIuu",
#                                 "expanded_url": "https://www.youtube.com/channel/UCo0V3hgs9ZnP0HDtzHaFRsA/about?sub_confirmation=1#socialblade",
#                                 "display_url": "youtube.com/channel/UCo0V3\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 458,
#                 "friends_count": 1506,
#                 "listed_count": 3,
#                 "created_at": "Fri Aug 09 00:06:35 +0000 2013",
#                 "favourites_count": 13983,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 9650,
#                 "lang": "es",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": true,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1001164354522263555/yWFUPJYY_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1001164354522263555/yWFUPJYY_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1656444234/1531157606",
#                 "profile_link_color": "E81C4F",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Sat Mar 30 23:59:43 +0000 2019",
#                 "id": 1112142390444335105,
#                 "id_str": "1112142390444335105",
#                 "text": "LOOK AT THIS VIEW \n\n#ULTRA2019 https://t.co/W7krqUijGV",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "ULTRA2019",
#                             "indices": [
#                                 20,
#                                 30
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1112142341094154240,
#                             "id_str": "1112142341094154240",
#                             "indices": [
#                                 31,
#                                 54
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                             "url": "https://t.co/W7krqUijGV",
#                             "display_url": "pic.twitter.com/W7krqUijGV",
#                             "expanded_url": "https://twitter.com/RafaaFreitass/status/1112142390444335105/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 675,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "large": {
#                                     "w": 1366,
#                                     "h": 768,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 382,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "id": 1112142341094154240,
#                             "id_str": "1112142341094154240",
#                             "indices": [
#                                 31,
#                                 54
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/D28fkRyWoAAjI7d.jpg",
#                             "url": "https://t.co/W7krqUijGV",
#                             "display_url": "pic.twitter.com/W7krqUijGV",
#                             "expanded_url": "https://twitter.com/RafaaFreitass/status/1112142390444335105/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 675,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "large": {
#                                     "w": 1366,
#                                     "h": 768,
#                                     "resize": "fit"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 382,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 55288283,
#                     "id_str": "55288283",
#                     "name": "Rafael Freitas",
#                     "screen_name": "RafaaFreitass",
#                     "location": "Porto Alegre, RS, Brasil",
#                     "description": "21. Ga\u00facho, Colorado, graduado em Geografia e amante de futebol e m\u00fasica eletr\u00f4nica.",
# ...
#                             "id": 1112120448366665729,
#                             "id_str": "1112120448366665729",
#                             "indices": [
#                                 103,
#                                 126
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/D28Lp9BX4AEZqZs.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/D28Lp9BX4AEZqZs.jpg",
#                             "url": "https://t.co/ET1YQJYD31",
#                             "display_url": "pic.twitter.com/ET1YQJYD31",
#                             "expanded_url": "https://twitter.com/widefuture/status/1112120478141947904/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "small": {
#                                     "w": 680,
#                                     "h": 678,
#                                     "resize": "fit"
#                                 },
#                                 "large": {
#                                     "w": 1206,
#                                     "h": 1202,
#                                     "resize": "fit"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 1196,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 2418181836,
#                     "id_str": "2418181836",
#                     "name": "WideFuture.com",
#                     "screen_name": "widefuture",
#                     "location": "Portugal",
#                     "description": "EVERYTHING ELECTRONIC DANCE MUSIC | News | Music | Podcasts | Mixes | Merch and much more! #WideFuture | #FutureConnection | #WearCulture",
#                     "url": "https://t.co/hcPFfLEHwH",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/hcPFfLEHwH",
#                                     "expanded_url": "http://www.widefuture.com",
#                                     "display_url": "widefuture.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 1627,
#                     "friends_count": 869,
#                     "listed_count": 46,
#                     "created_at": "Sun Mar 30 00:32:59 +0000 2014",
#                     "favourites_count": 3938,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": false,
#                     "statuses_count": 16119,
#                     "lang": "en",
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "0E3DF5",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#                     "profile_background_tile": true,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/949329693806821376/hbeyNQZS_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/949329693806821376/hbeyNQZS_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/2418181836/1546576074",
#                     "profile_link_color": "E81C4F",
#                     "profile_sidebar_border_color": "FFFFFF",
#                     "profile_sidebar_fill_color": "EFEFEF",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none"
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 75,
#                 "favorite_count": 210,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 75,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sat Mar 30 23:55:43 +0000 2019",
#             "id": 1112141386244153344,
#             "id_str": "1112141386244153344",
#             "text": "Jumpppppp Mother fuckers!!!! \ud83d\ude4c\ud83c\udffc\ud83d\ude4c\ud83c\udffc\ud83d\ude4c\ud83c\udffc #Ultra2019",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Ultra2019",
#                         "indices": [
#                             36,
#                             46
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1085317564492849152,
#                 "id_str": "1085317564492849152",
#                 "name": "C\u03b1\u044fii J\u03b1ck\u0e23\u03c3\u0438 | ULTRA | MARIA \u2661",
#                 "screen_name": "SexyCre4tivee",
#                 "location": "Los Angeles, CA",
#                 "description": "\u26a0\ufe0f\u2202\u03c3\u03b7'\u0442 \u043d\u03b1\u0442\u0454 \u0442\u043d\u0454 \u03c1\u0142\u03b1\u10e7\u0454\u044f ,\u043d\u03b1\u0442\u0454 \u0442\u043d\u0454 g\u03b1\u043c\u0454\u26a0\ufe0f             i\u0192 y\u03c3\u03c5 c\u03b1\u0e17'\u03c4 \u0192i\u0e17\u2202 \u03b1 \u03c9\u03b1y, cr\u0454\u03b1\u03c4\u0454 \u03c3\u0e17\u0454!",
#                 "url": "https://t.co/v6p3DBR8Jw",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/v6p3DBR8Jw",
#                                 "expanded_url": "http://www.instagram.com/cre4tivedmusic",
#                                 "display_url": "instagram.com/cre4tivedmusic",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 23,
#                 "friends_count": 55,
#                 "listed_count": 0,
#                 "created_at": "Tue Jan 15 23:27:26 +0000 2019",
#                 "favourites_count": 850,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 1073,
#                 "lang": "pt",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1107001432564293634/TCV7xfw5_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1107001432564293634/TCV7xfw5_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1085317564492849152/1547595513",
#                 "profile_link_color": "1B95E0",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 1,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Sat Mar 30 23:55:41 +0000 2019",
#             "id": 1112141378501394434,
#             "id_str": "1112141378501394434",
#             "text": "Don't let me down #Ultra2019",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Ultra2019",
#                         "indices": [
#                             18,
#                             28
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1656444234,
#                 "id_str": "1656444234",
#                 "name": "\u25e2\u25e4Manuel Aquino Lay \u25e2\u25e4",
#                 "screen_name": "manuelaquino03",
#                 "location": "Santo Domingo Dominican Rep.",
#                 "description": "Estudiante de Ingenier\u00eda Electr\u00f3nica, y Amante la M\u00fasica Electr\u00f3nica en especial el Hardstyle, Trance, EDM Big Room y Progressive House\nInstagram: Manuel_AL003",
#                 "url": "https://t.co/ZBvZ3XoIuu",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/ZBvZ3XoIuu",
#                                 "expanded_url": "https://www.youtube.com/channel/UCo0V3hgs9ZnP0HDtzHaFRsA/about?sub_confirmation=1#socialblade",
#                                 "display_url": "youtube.com/channel/UCo0V3\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 458,
#                 "friends_count": 1506,
#                 "listed_count": 3,
#                 "created_at": "Fri Aug 09 00:06:35 +0000 2013",
#                 "favourites_count": 13983,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 9650,
#                 "lang": "es",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": true,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1001164354522263555/yWFUPJYY_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1001164354522263555/yWFUPJYY_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1656444234/1531157606",
#                 "profile_link_color": "E81C4F",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         }
#     ],
#     "search_metadata": {
#         "completed_in": 0.13,
#         "max_id": 1112142455955251200,
#         "max_id_str": "1112142455955251200",
#         "next_results": "?max_id=1110940375609475071&q=%23ultra2019%20until%3A2019-03-31&lang=en&count=100&include_entities=1&result_type=mixed",
#         "query": "%23ultra2019+until%3A2019-03-31",
#         "refresh_url": "?since_id=1112142455955251200&q=%23ultra2019%20until%3A2019-03-31&lang=en&result_type=mixed&include_entities=1",
#         "count": 100,
#         "since_id": 0,
#         "since_id_str": "0"
#     }
# }

# %%
hashtags=results['statuses'][3]['entities']['hashtags']
print(json.dumps(hashtags,indent=4))
# Out:
# [
#     {
#         "text": "Ultra2019",
#         "indices": [
#             59,
#             69
#         ]
#     },
#     {
#         "text": "ULTRALIVE",
#         "indices": [
#             70,
#             80
#         ]
#     }
# ]

# %%
data=results['statuses']
print(len(results['statuses']))
#print(data[1]['text'])
df=pd.DataFrame.from_dict(data)
df
# Out:
# 100
#    contributors coordinates                      created_at  \
# 0          None        None  Wed Mar 27 16:23:20 +0000 2019
# 1          None        None  Sat Mar 30 02:22:59 +0000 2019
# 2          None        None  Sat Mar 30 13:49:00 +0000 2019
# 3          None        None  Sat Mar 30 23:59:58 +0000 2019
# 4          None        None  Sat Mar 30 23:59:57 +0000 2019
# 5          None        None  Sat Mar 30 23:59:55 +0000 2019
# 6          None        None  Sat Mar 30 23:59:55 +0000 2019
# 7          None        None  Sat Mar 30 23:59:52 +0000 2019
# 8          None        None  Sat Mar 30 23:59:52 +0000 2019
# 9          None        None  Sat Mar 30 23:59:51 +0000 2019
# 10         None        None  Sat Mar 30 23:59:49 +0000 2019
# 11         None        None  Sat Mar 30 23:59:48 +0000 2019
# 12         None        None  Sat Mar 30 23:59:46 +0000 2019
# 13         None        None  Sat Mar 30 23:59:45 +0000 2019
# 14         None        None  Sat Mar 30 23:59:45 +0000 2019
# 15         None        None  Sat Mar 30 23:59:44 +0000 2019
# 16         None        None  Sat Mar 30 23:59:43 +0000 2019
# 17         None        None  Sat Mar 30 23:59:42 +0000 2019
# 18         None        None  Sat Mar 30 23:59:42 +0000 2019
# 19         None        None  Sat Mar 30 23:59:41 +0000 2019
# 20         None        None  Sat Mar 30 23:59:38 +0000 2019
# 21         None        None  Sat Mar 30 23:59:38 +0000 2019
# 22         None        None  Sat Mar 30 23:59:35 +0000 2019
# 23         None        None  Sat Mar 30 23:59:34 +0000 2019
# 24         None        None  Sat Mar 30 23:59:32 +0000 2019
# 25         None        None  Sat Mar 30 23:59:31 +0000 2019
# 26         None        None  Sat Mar 30 23:59:29 +0000 2019
# 27         None        None  Sat Mar 30 23:59:29 +0000 2019
# 28         None        None  Sat Mar 30 23:59:28 +0000 2019
# 29         None        None  Sat Mar 30 23:59:26 +0000 2019
# ..          ...         ...                             ...
# 70         None        None  Sat Mar 30 23:57:04 +0000 2019
# 71         None        None  Sat Mar 30 23:57:02 +0000 2019
# 72         None        None  Sat Mar 30 23:57:02 +0000 2019
# 73         None        None  Sat Mar 30 23:56:57 +0000 2019
# 74         None        None  Sat Mar 30 23:56:55 +0000 2019
# 75         None        None  Sat Mar 30 23:56:48 +0000 2019
# 76         None        None  Sat Mar 30 23:56:47 +0000 2019
# 77         None        None  Sat Mar 30 23:56:47 +0000 2019
# 78         None        None  Sat Mar 30 23:56:41 +0000 2019
# 79         None        None  Sat Mar 30 23:56:34 +0000 2019
# 80         None        None  Sat Mar 30 23:56:28 +0000 2019
# 81         None        None  Sat Mar 30 23:56:21 +0000 2019
# 82         None        None  Sat Mar 30 23:56:20 +0000 2019
# 83         None        None  Sat Mar 30 23:56:10 +0000 2019
# 84         None        None  Sat Mar 30 23:56:09 +0000 2019
# 85         None        None  Sat Mar 30 23:56:04 +0000 2019
# 86         None        None  Sat Mar 30 23:56:03 +0000 2019
# 87         None        None  Sat Mar 30 23:56:00 +0000 2019
# 88         None        None  Sat Mar 30 23:56:00 +0000 2019
# 89         None        None  Sat Mar 30 23:55:58 +0000 2019
# 90         None        None  Sat Mar 30 23:55:51 +0000 2019
# 91         None        None  Sat Mar 30 23:55:51 +0000 2019
# 92         None        None  Sat Mar 30 23:55:51 +0000 2019
# 93         None        None  Sat Mar 30 23:55:50 +0000 2019
# 94         None        None  Sat Mar 30 23:55:49 +0000 2019
# 95         None        None  Sat Mar 30 23:55:48 +0000 2019
# 96         None        None  Sat Mar 30 23:55:44 +0000 2019
# 97         None        None  Sat Mar 30 23:55:44 +0000 2019
# 98         None        None  Sat Mar 30 23:55:43 +0000 2019
# 99         None        None  Sat Mar 30 23:55:41 +0000 2019
#
#                                              entities  \
# 0   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 1   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 2   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 3   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 4   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 5   {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 6   {'hashtags': [{'text': 'UltraMiami2019', 'indi...
# 7   {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 8   {'hashtags': [{'text': 'ultra2019', 'indices':...
# 9   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 10  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 11  {'hashtags': [], 'symbols': [], 'user_mentions...
# 12  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 13  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 14  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 15  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 16  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 17  {'hashtags': [], 'symbols': [], 'user_mentions...
# 18  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 19  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 20  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 21  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 22  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 23  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 24  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 25  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 26  {'hashtags': [{'text': 'Tiesto', 'indices': [5...
# 27  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 28  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 29  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# ..                                                ...
# 70  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 71  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 72  {'hashtags': [{'text': 'Ultralive', 'indices':...
# 73  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 74  {'hashtags': [], 'symbols': [], 'user_mentions...
# 75  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 77  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 78  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 79  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 80  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 81  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 82  {'hashtags': [{'text': 'UltraMiami2019', 'indi...
# 83  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 84  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 85  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 86  {'hashtags': [], 'symbols': [], 'user_mentions...
# 87  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 88  {'hashtags': [], 'symbols': [], 'user_mentions...
# 89  {'hashtags': [{'text': 'UltraMiami2019', 'indi...
# 90  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 91  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 92  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 93  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 94  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 95  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 96  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 97  {'hashtags': [{'text': 'Ultralive', 'indices':...
# 98  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 99  {'hashtags': [{'text': 'Ultra2019', 'indices':...
#
#                                     extended_entities  favorite_count  \
# 0   {'media': [{'id': 1110939659557892096, 'id_str...            4135
# 1                                                 NaN            3968
# 2                                                 NaN            1860
# 3                                                 NaN               0
# 4                                                 NaN               1
# 5   {'media': [{'id': 1112142341094154240, 'id_str...               0
# 6   {'media': [{'id': 1112142417887670273, 'id_str...               0
# 7                                                 NaN               2
# 8   {'media': [{'id': 1111919152510500864, 'id_str...               0
# 9                                                 NaN               2
# 10                                                NaN               1
# 11                                                NaN               0
# 12                                                NaN               2
# 13                                                NaN               1
# 14                                                NaN               1
# 15  {'media': [{'id': 1112138705198817283, 'id_str...               0
# 16  {'media': [{'id': 1112142341094154240, 'id_str...               9
# 17                                                NaN               0
# 18                                                NaN               1
# 19                                                NaN               0
# 20                                                NaN               1
# 21                                                NaN               1
# 22                                                NaN               1
# 23                                                NaN               0
# 24                                                NaN               4
# 25                                                NaN               2
# 26                                                NaN               0
# 27                                                NaN               2
# 28                                                NaN               4
# 29                                                NaN               1
# ..                                                ...             ...
# 70                                                NaN               0
# 71                                                NaN               0
# 72                                                NaN               0
# 73                                                NaN               0
# 74                                                NaN               0
# 75                                                NaN               0
# 76                                                NaN               2
# 77                                                NaN               0
# 78                                                NaN               0
# 79                                                NaN               0
# 80                                                NaN               0
# 81                                                NaN               0
# 82  {'media': [{'id': 1112141536530182144, 'id_str...               0
# 83                                                NaN               0
# 84  {'media': [{'id': 1112140552139612160, 'id_str...               0
# 85  {'media': [{'id': 1112141302483873794, 'id_str...               0
# 86                                                NaN               0
# 87  {'media': [{'id': 1112141432335355904, 'id_str...               0
# 88                                                NaN               0
# 89  {'media': [{'id': 1112141435187294209, 'id_str...               1
# 90                                                NaN               0
# 91  {'media': [{'id': 1112141302483873794, 'id_str...               0
# 92  {'media': [{'id': 1112141302483873794, 'id_str...               0
# 93  {'media': [{'id': 1112083448359985153, 'id_str...               0
# 94                                                NaN               0
# 95  {'media': [{'id': 1112141302483873794, 'id_str...               0
# 96                                                NaN               0
# 97                                                NaN               0
# 98                                                NaN               1
# 99                                                NaN               0
#
#     favorited   geo                   id               id_str  \
# 0       False  None  1110940375609475072  1110940375609475072
# 1       False  None  1111816056924966912  1111816056924966912
# 2       False  None  1111988698961182730  1111988698961182730
# 3       False  None  1112142455955251200  1112142455955251200
# 4       False  None  1112142451379261441  1112142451379261441
# 5       False  None  1112142441451266050  1112142441451266050
# 6       False  None  1112142440994140161  1112142440994140161
# 7       False  None  1112142427995938816  1112142427995938816
# 8       False  None  1112142427849220096  1112142427849220096
# 9       False  None  1112142424904732672  1112142424904732672
# 10      False  None  1112142417183035392  1112142417183035392
# 11      False  None  1112142414918107137  1112142414918107137
# 12      False  None  1112142404310560768  1112142404310560768
# 13      False  None  1112142400368140290  1112142400368140290
# 14      False  None  1112142399302782982  1112142399302782982
# 15      False  None  1112142396895068160  1112142396895068160
# 16      False  None  1112142390444335105  1112142390444335105
# 17      False  None  1112142387713900545  1112142387713900545
# 18      False  None  1112142387491557377  1112142387491557377
# 19      False  None  1112142383481647105  1112142383481647105
# 20      False  None  1112142372991717377  1112142372991717377
# 21      False  None  1112142372694093825  1112142372694093825
# 22      False  None  1112142359222013953  1112142359222013953
# 23      False  None  1112142355212177408  1112142355212177408
# 24      False  None  1112142347070902272  1112142347070902272
# 25      False  None  1112142341291290624  1112142341291290624
# 26      False  None  1112142332311199744  1112142332311199744
# 27      False  None  1112142331178819585  1112142331178819585
# 28      False  None  1112142327391363073  1112142327391363073
# 29      False  None  1112142322358194179  1112142322358194179
# ..        ...   ...                  ...                  ...
# 70      False  None  1112141723461959682  1112141723461959682
# 71      False  None  1112141718210510848  1112141718210510848
# 72      False  None  1112141717925519361  1112141717925519361
# 73      False  None  1112141697679417344  1112141697679417344
# 74      False  None  1112141685457412096  1112141685457412096
# 75      False  None  1112141657523322882  1112141657523322882
# 76      False  None  1112141653295403009  1112141653295403009
# 77      False  None  1112141652297240576  1112141652297240576
# 78      False  None  1112141629912166403  1112141629912166403
# 79      False  None  1112141599566454785  1112141599566454785
# 80      False  None  1112141575902117891  1112141575902117891
# 81      False  None  1112141543186579456  1112141543186579456
# 82      False  None  1112141542448340992  1112141542448340992
# 83      False  None  1112141497477095424  1112141497477095424
# 84      False  None  1112141494830460928  1112141494830460928
# 85      False  None  1112141473372356610  1112141473372356610
# 86      False  None  1112141469148680192  1112141469148680192
# 87      False  None  1112141458247745537  1112141458247745537
# 88      False  None  1112141454867120129  1112141454867120129
# 89      False  None  1112141446298009600  1112141446298009600
# 90      False  None  1112141419022635009  1112141419022635009
# 91      False  None  1112141418867376131  1112141418867376131
# 92      False  None  1112141418607398912  1112141418607398912
# 93      False  None  1112141412613664768  1112141412613664768
# 94      False  None  1112141409082109954  1112141409082109954
# 95      False  None  1112141406586441728  1112141406586441728
# 96      False  None  1112141390920761344  1112141390920761344
# 97      False  None  1112141390744559618  1112141390744559618
# 98      False  None  1112141386244153344  1112141386244153344
# 99      False  None  1112141378501394434  1112141378501394434
#
#                           ...                         quoted_status  \
# 0                         ...                                   NaN
# 1                         ...                                   NaN
# 2                         ...                                   NaN
# 3                         ...                                   NaN
# 4                         ...                                   NaN
# 5                         ...                                   NaN
# 6                         ...                                   NaN
# 7                         ...                                   NaN
# 8                         ...                                   NaN
# 9                         ...                                   NaN
# 10                        ...                                   NaN
# 11                        ...                                   NaN
# 12                        ...                                   NaN
# 13                        ...                                   NaN
# 14                        ...                                   NaN
# 15                        ...                                   NaN
# 16                        ...                                   NaN
# 17                        ...                                   NaN
# 18                        ...                                   NaN
# 19                        ...                                   NaN
# 20                        ...                                   NaN
# 21                        ...                                   NaN
# 22                        ...                                   NaN
# 23                        ...                                   NaN
# 24                        ...                                   NaN
# 25                        ...                                   NaN
# 26                        ...                                   NaN
# 27                        ...                                   NaN
# 28                        ...                                   NaN
# 29                        ...                                   NaN
# ..                        ...                                   ...
# 70                        ...                                   NaN
# 71                        ...                                   NaN
# 72                        ...                                   NaN
# 73                        ...                                   NaN
# 74                        ...                                   NaN
# 75                        ...                                   NaN
# 76                        ...                                   NaN
# 77                        ...                                   NaN
# 78                        ...                                   NaN
# 79                        ...                                   NaN
# 80                        ...                                   NaN
# 81                        ...                                   NaN
# 82                        ...                                   NaN
# 83                        ...                                   NaN
# 84                        ...                                   NaN
# 85                        ...                                   NaN
# 86                        ...                                   NaN
# 87                        ...                                   NaN
# 88                        ...                                   NaN
# 89                        ...                                   NaN
# 90                        ...                                   NaN
# 91                        ...                                   NaN
# 92                        ...                                   NaN
# 93                        ...                                   NaN
# 94                        ...                                   NaN
# 95                        ...                                   NaN
# 96                        ...                                   NaN
# 97                        ...                                   NaN
# 98                        ...                                   NaN
# 99                        ...                                   NaN
#
#     quoted_status_id quoted_status_id_str  retweet_count retweeted  \
# 0                NaN                  NaN           1016     False
# 1                NaN                  NaN            818     False
# 2                NaN                  NaN            418     False
# 3                NaN                  NaN              8     False
# 4                NaN                  NaN              1     False
# 5                NaN                  NaN              4     False
# 6                NaN                  NaN              0     False
# 7                NaN                  NaN              0     False
# 8                NaN                  NaN            229     False
# 9                NaN                  NaN              0     False
# 10               NaN                  NaN              0     False
# 11               NaN                  NaN           1604     False
# 12               NaN                  NaN              0     False
# 13               NaN                  NaN              0     False
# 14               NaN                  NaN              0     False
# 15               NaN                  NaN             40     False
# 16               NaN                  NaN              4     False
# 17      1.111880e+18  1111880344838524928            216     False
# 18               NaN                  NaN              1     False
# 19               NaN                  NaN              0     False
# 20               NaN                  NaN              0     False
# 21               NaN                  NaN              0     False
# 22               NaN                  NaN              0     False
# 23               NaN                  NaN              0     False
# 24               NaN                  NaN              0     False
# 25               NaN                  NaN              0     False
# 26               NaN                  NaN              4     False
# 27               NaN                  NaN              0     False
# 28               NaN                  NaN              0     False
# 29               NaN                  NaN              1     False
# ..               ...                  ...            ...       ...
# 70               NaN                  NaN            818     False
# 71               NaN                  NaN           1048     False
# 72               NaN                  NaN             75     False
# 73               NaN                  NaN            289     False
# 74               NaN                  NaN           1604     False
# 75               NaN                  NaN            509     False
# 76               NaN                  NaN              0     False
# 77               NaN                  NaN              7     False
# 78               NaN                  NaN              0     False
# 79               NaN                  NaN              0     False
# 80               NaN                  NaN              1     False
# 81               NaN                  NaN              0     False
# 82               NaN                  NaN              0     False
# 83               NaN                  NaN              0     False
# 84               NaN                  NaN              1     False
# 85               NaN                  NaN             20     False
# 86               NaN                  NaN             82     False
# 87               NaN                  NaN              0     False
# 88               NaN                  NaN             78     False
# 89               NaN                  NaN              0     False
# 90               NaN                  NaN              0     False
# 91               NaN                  NaN             20     False
# 92               NaN                  NaN             20     False
# 93               NaN                  NaN            618     False
# 94               NaN                  NaN              0     False
# 95               NaN                  NaN             20     False
# 96               NaN                  NaN              1     False
# 97               NaN                  NaN             75     False
# 98               NaN                  NaN              1     False
# 99               NaN                  NaN              0     False
#
#                                      retweeted_status  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   {'created_at': 'Sat Mar 30 23:47:41 +0000 2019...
# 4                                                 NaN
# 5   {'created_at': 'Sat Mar 30 23:59:43 +0000 2019...
# 6                                                 NaN
# 7                                                 NaN
# 8   {'created_at': 'Sat Mar 30 09:12:47 +0000 2019...
# 9                                                 NaN
# 10                                                NaN
# 11  {'created_at': 'Sat Mar 30 06:38:26 +0000 2019...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'created_at': 'Sat Mar 30 23:45:05 +0000 2019...
# 16                                                NaN
# 17  {'created_at': 'Sat Mar 30 06:48:46 +0000 2019...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  {'created_at': 'Sat Mar 30 18:22:39 +0000 2019...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 70  {'created_at': 'Sat Mar 30 02:22:59 +0000 2019...
# 71  {'created_at': 'Sat Mar 30 22:55:33 +0000 2019...
# 72  {'created_at': 'Sat Mar 30 22:32:38 +0000 2019...
# 73  {'created_at': 'Sat Mar 30 22:45:14 +0000 2019...
# 74  {'created_at': 'Sat Mar 30 06:38:26 +0000 2019...
# 75  {'created_at': 'Sat Mar 30 08:19:05 +0000 2019...
# 76                                                NaN
# 77  {'created_at': 'Sat Mar 30 23:53:38 +0000 2019...
# 78                                                NaN
# 79                                                NaN
# 80  {'created_at': 'Sat Mar 30 23:55:43 +0000 2019...
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84  {'created_at': 'Sat Mar 30 23:52:30 +0000 2019...
# 85  {'created_at': 'Sat Mar 30 23:55:27 +0000 2019...
# 86  {'created_at': 'Sat Mar 30 21:18:38 +0000 2019...
# 87                                                NaN
# 88  {'created_at': 'Sat Mar 30 21:18:38 +0000 2019...
# 89                                                NaN
# 90                                                NaN
# 91  {'created_at': 'Sat Mar 30 23:55:27 +0000 2019...
# 92  {'created_at': 'Sat Mar 30 23:55:27 +0000 2019...
# 93  {'created_at': 'Sat Mar 30 20:05:58 +0000 2019...
# 94                                                NaN
# 95  {'created_at': 'Sat Mar 30 23:55:27 +0000 2019...
# 96  {'created_at': 'Sat Mar 30 23:55:07 +0000 2019...
# 97  {'created_at': 'Sat Mar 30 22:32:38 +0000 2019...
# 98                                                NaN
# 99                                                NaN
#
#                                                source  \
# 0   <a href="https://studio.twitter.com" rel="nofo...
# 1   <a href="http://twitter.com/download/iphone" r...
# 2   <a href="https://studio.twitter.com" rel="nofo...
# 3   <a href="https://mobile.twitter.com" rel="nofo...
# 4   <a href="http://twitter.com/download/android" ...
# 5   <a href="http://twitter.com" rel="nofollow">Tw...
# 6   <a href="http://twitter.com/download/android" ...
# 7   <a href="http://twitter.com" rel="nofollow">Tw...
# 8   <a href="http://twitter.com/download/iphone" r...
# 9   <a href="http://twitter.com" rel="nofollow">Tw...
# 10  <a href="http://twitter.com" rel="nofollow">Tw...
# 11  <a href="http://twitter.com/download/android" ...
# 12  <a href="http://twitter.com/download/android" ...
# 13  <a href="http://twitter.com/download/iphone" r...
# 14  <a href="http://twitter.com" rel="nofollow">Tw...
# 15  <a href="http://twitter.com/download/iphone" r...
# 16  <a href="http://twitter.com" rel="nofollow">Tw...
# 17  <a href="http://twitter.com/download/android" ...
# 18  <a href="http://twitter.com/download/android" ...
# 19  <a href="http://twitter.com/download/iphone" r...
# 20  <a href="http://twitter.com/download/iphone" r...
# 21  <a href="http://twitter.com/download/iphone" r...
# 22  <a href="http://twitter.com/download/android" ...
# 23  <a href="http://twitter.com/download/android" ...
# 24  <a href="http://twitter.com/download/iphone" r...
# 25  <a href="http://twitter.com/download/iphone" r...
# 26  <a href="http://twitter.com/download/android" ...
# 27  <a href="http://twitter.com/download/android" ...
# 28  <a href="http://twitter.com/download/iphone" r...
# 29  <a href="http://twitter.com/download/android" ...
# ..                                                ...
# 70  <a href="http://twitter.com/download/android" ...
# 71  <a href="http://twitter.com/download/iphone" r...
# 72  <a href="http://twitter.com/download/iphone" r...
# 73  <a href="http://twitter.com/download/iphone" r...
# 74  <a href="http://twitter.com/download/iphone" r...
# 75  <a href="http://twitter.com/download/android" ...
# 76  <a href="http://twitter.com/download/iphone" r...
# 77  <a href="https://mobile.twitter.com" rel="nofo...
# 78  <a href="http://twitter.com/download/android" ...
# 79  <a href="https://mobile.twitter.com" rel="nofo...
# 80  <a href="http://twitter.com/download/android" ...
# 81  <a href="http://twitter.com/download/android" ...
# 82  <a href="http://twitter.com/download/android" ...
# 83  <a href="https://about.twitter.com/products/tw...
# 84  <a href="http://twitter.com/download/android" ...
# 85  <a href="http://twitter.com/download/android" ...
# 86  <a href="http://twitter.com/download/android" ...
# 87  <a href="http://twitter.com/download/android" ...
# 88  <a href="http://twitter.com/download/android" ...
# 89  <a href="http://twitter.com/download/android" ...
# 90  <a href="http://twitter.com/download/android" ...
# 91  <a href="http://twitter.com/download/android" ...
# 92  <a href="http://twitter.com/download/android" ...
# 93  <a href="https://mobile.twitter.com" rel="nofo...
# 94  <a href="http://twitter.com/download/iphone" r...
# 95  <a href="http://twitter.com/download/android" ...
# 96  <a href="http://twitter.com/download/android" ...
# 97  <a href="http://twitter.com/download/android" ...
# 98  <a href="http://twitter.com/download/android" ...
# 99  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                  text truncated  \
# 0   MIAMI, ARE YOU READY?\n\nOnly 2 more days unti...     False
# 1                    WE COULD BE HEROES\n\n#Ultra2019     False
# 2   Are you ready for #Ultra2019?🙌 Get in the mood...      True
# 3   RT @lllucia_: PARDON MY FRENCH IN THE HOUSE. @...     False
# 4                        FATHER OF HOUSEEE #Ultra2019     False
# 5   RT @RafaaFreitass: LOOK AT THIS VIEW \n\n#ULTR...     False
# 6   I love the church of @iamTchami #UltraMiami201...     False
# 7                           NOBODY ELSE\n\n#ULTRA2019     False
# 8   RT @DylanBrett00: #ultra2019 80k people strand...     False
# 9                     NOBODY ELSE #Ultra2019 #UMF2019     False
# 10       @iamTchami crushing it @ultra #Ultra2019 🙌🙌🙌     False
# 11  RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2....     False
# 12                         AWESOME music!  #Ultra2019     False
# 13                #ultra2019 let’s goooo from Russia)     False
# 14                     NOBODY ELSEEEEEEEEE #ULTRA2019     False
# 15  RT @UMFTV: Put your hands up for Tchami at #Ul...     False
# 16  LOOK AT THIS VIEW \n\n#ULTRA2019 https://t.co/...     False
# 17  RT @EDMManiac: BREAKING: multiple reports of a...     False
# 18                 Ultra is my religion ❤️ #Ultra2019     False
# 19                      dat tchami visual  #ultra2019     False
# 20  Not at #Ultra2019 but doing the next best thin...     False
# 21                          NOBODYELSEEEEE #ULTRA2019     False
# 22              #Ultra2019 Waiting for Martin Garrix!     False
# 23  Day 2 Ultra Live Steam. Let's get it 😘 #ultra2019     False
# 24                       #Ultra2019 heeeeeeyyy tchami     False
# 25           Nobody else, Nobody else 🔥 #ULTRA2019 🇺🇸     False
# 26  RT @edmalertcom: Ultra Music Festival Live Set...     False
# 27                            NOBODY ELSEE #Ultra2019     False
# 28  If I can’t have you,\nI don’t want nobody else...     False
# 29            TCHAMI is on! #Ultra2019 ♥ \nYaaaay!!!!     False
# ..                                                ...       ...
# 70        RT @ultra: WE COULD BE HEROES\n\n#Ultra2019     False
# 71  RT @dancingastro: Ultra day 2 is already snapp...     False
# 72  RT @widefuture: Street artist, Royal Dog, is p...     False
# 73  RT @ultra: Wow, @SHAQ and @LilJon are on stage...     False
# 74  RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2....     False
# 75  RT @Tidoublemy8: Tens of thousands of people l...     False
# 76  My grandma is better than yours bc she have me...     False
# 77  RT @lllucia_: DON'T LET ME DOWN❤ #Ultra2019 #U...     False
# 78                                GO GO GO #Ultra2019     False
# 79                     Tchami is killin it #Ultra2019     False
# 80  RT @SexyCre4tivee: Jumpppppp Mother fuckers!!!...     False
# 81               @iamTchami is my father!! #Ultra2019     False
# 82  I'd hate to be those walking miles back to the...     False
# 83                  Let's go our frenchy ! #Ultra2019     False
# 84  RT @Menjivar019: PARDON MY FRENCH. 🇫🇷🇫🇷 @iamTc...     False
# 85  RT @FestEnfurecido: Skyline #Ultra2019 https:/...     False
# 86  RT @ultra: - Implementing comprehensive transp...     False
# 87  #ultra2019  this was set with @iamTchami https...     False
# 88  RT @ultra: We have been hard at work ensuring ...     False
# 89  Thanks for the stream @diplo @Carl_Cox 🔥🔥🔥🕺 #U...     False
# 90        #ultra2019 is trash for doing that KFC shit     False
# 91  RT @FestEnfurecido: Skyline #Ultra2019 https:/...     False
# 92  RT @FestEnfurecido: Skyline #Ultra2019 https:/...     False
# 93  RT @ultra: Thank you, Miami, for an unforgetta...     False
# 94                   I LOVE YOU @iamTchami #Ultra2019     False
# 95  RT @FestEnfurecido: Skyline #Ultra2019 https:/...     False
# 96  RT @SexyCre4tivee: Beautiful view!!❤️❤️❤️ #Ult...     False
# 97  RT @widefuture: Street artist, Royal Dog, is p...     False
# 98     Jumpppppp Mother fuckers!!!! 🙌🏼🙌🏼🙌🏼 #Ultra2019     False
# 99                       Don't let me down #Ultra2019     False
#
#                                                  user
# 0   {'id': 22838300, 'id_str': '22838300', 'name':...
# 1   {'id': 22838300, 'id_str': '22838300', 'name':...
# 2   {'id': 21787625, 'id_str': '21787625', 'name':...
# 3   {'id': 859597306953441283, 'id_str': '85959730...
# 4   {'id': 2167192151, 'id_str': '2167192151', 'na...
# 5   {'id': 1656444234, 'id_str': '1656444234', 'na...
# 6   {'id': 707423014472826881, 'id_str': '70742301...
# 7   {'id': 55288283, 'id_str': '55288283', 'name':...
# 8   {'id': 2993513884, 'id_str': '2993513884', 'na...
# 9   {'id': 1114170733, 'id_str': '1114170733', 'na...
# 10  {'id': 40304338, 'id_str': '40304338', 'name':...
# 11  {'id': 1240090370, 'id_str': '1240090370', 'na...
# 12  {'id': 1303805886, 'id_str': '1303805886', 'na...
# 13  {'id': 169628144, 'id_str': '169628144', 'name...
# 14  {'id': 268285342, 'id_str': '268285342', 'name...
# 15  {'id': 2546194862, 'id_str': '2546194862', 'na...
# 16  {'id': 55288283, 'id_str': '55288283', 'name':...
# 17  {'id': 89851534, 'id_str': '89851534', 'name':...
# 18  {'id': 1085317564492849152, 'id_str': '1085317...
# 19  {'id': 932431037296099328, 'id_str': '93243103...
# 20  {'id': 22672698, 'id_str': '22672698', 'name':...
# 21  {'id': 341772462, 'id_str': '341772462', 'name...
# 22  {'id': 876313957, 'id_str': '876313957', 'name...
# 23  {'id': 24098519, 'id_str': '24098519', 'name':...
# 24  {'id': 146724500, 'id_str': '146724500', 'name...
# 25  {'id': 4637459417, 'id_str': '4637459417', 'na...
# 26  {'id': 1057567202, 'id_str': '1057567202', 'na...
# 27  {'id': 3409096841, 'id_str': '3409096841', 'na...
# 28  {'id': 352375460, 'id_str': '352375460', 'name...
# 29  {'id': 1052196956, 'id_str': '1052196956', 'na...
# ..                                                ...
# 70  {'id': 2230257780, 'id_str': '2230257780', 'na...
# 71  {'id': 499364377, 'id_str': '499364377', 'name...
# 72  {'id': 1030472917757435904, 'id_str': '1030472...
# 73  {'id': 866465990, 'id_str': '866465990', 'name...
# 74  {'id': 174411694, 'id_str': '174411694', 'name...
# 75  {'id': 755264957630021632, 'id_str': '75526495...
# 76  {'id': 2155616608, 'id_str': '2155616608', 'na...
# 77  {'id': 865716874914529281, 'id_str': '86571687...
# 78  {'id': 2167192151, 'id_str': '2167192151', 'na...
# 79  {'id': 59895419, 'id_str': '59895419', 'name':...
# 80  {'id': 2167192151, 'id_str': '2167192151', 'na...
# 81  {'id': 2167192151, 'id_str': '2167192151', 'na...
# 82  {'id': 835819827335950337, 'id_str': '83581982...
# 83  {'id': 2617039994, 'id_str': '2617039994', 'na...
# 84  {'id': 1716915108, 'id_str': '1716915108', 'na...
# 85  {'id': 2948953792, 'id_str': '2948953792', 'na...
# 86  {'id': 586178748, 'id_str': '586178748', 'name...
# 87  {'id': 916432598653657089, 'id_str': '91643259...
# 88  {'id': 586178748, 'id_str': '586178748', 'name...
# 89  {'id': 908571199348785152, 'id_str': '90857119...
# 90  {'id': 141060040, 'id_str': '141060040', 'name...
# 91  {'id': 1085317564492849152, 'id_str': '1085317...
# 92  {'id': 628314035, 'id_str': '628314035', 'name...
# 93  {'id': 86443294, 'id_str': '86443294', 'name':...
# 94  {'id': 262983717, 'id_str': '262983717', 'name...
# 95  {'id': 319831433, 'id_str': '319831433', 'name...
# 96  {'id': 2167192151, 'id_str': '2167192151', 'na...
# 97  {'id': 1719186421, 'id_str': '1719186421', 'na...
# 98  {'id': 1085317564492849152, 'id_str': '1085317...
# 99  {'id': 1656444234, 'id_str': '1656444234', 'na...
#
# [100 rows x 30 columns]

# %%
df_clean=df[['created_at','favorite_count','retweet_count','text','entities']]

# %%
df_clean
# Out:
#                         created_at  favorite_count  retweet_count  \
# 0   Wed Mar 27 16:23:20 +0000 2019            4135           1016
# 1   Sat Mar 30 02:22:59 +0000 2019            3968            818
# 2   Sat Mar 30 13:49:00 +0000 2019            1860            418
# 3   Sat Mar 30 23:59:58 +0000 2019               0              8
# 4   Sat Mar 30 23:59:57 +0000 2019               1              1
# 5   Sat Mar 30 23:59:55 +0000 2019               0              4
# 6   Sat Mar 30 23:59:55 +0000 2019               0              0
# 7   Sat Mar 30 23:59:52 +0000 2019               2              0
# 8   Sat Mar 30 23:59:52 +0000 2019               0            229
# 9   Sat Mar 30 23:59:51 +0000 2019               2              0
# 10  Sat Mar 30 23:59:49 +0000 2019               1              0
# 11  Sat Mar 30 23:59:48 +0000 2019               0           1604
# 12  Sat Mar 30 23:59:46 +0000 2019               2              0
# 13  Sat Mar 30 23:59:45 +0000 2019               1              0
# 14  Sat Mar 30 23:59:45 +0000 2019               1              0
# 15  Sat Mar 30 23:59:44 +0000 2019               0             40
# 16  Sat Mar 30 23:59:43 +0000 2019               9              4
# 17  Sat Mar 30 23:59:42 +0000 2019               0            216
# 18  Sat Mar 30 23:59:42 +0000 2019               1              1
# 19  Sat Mar 30 23:59:41 +0000 2019               0              0
# 20  Sat Mar 30 23:59:38 +0000 2019               1              0
# 21  Sat Mar 30 23:59:38 +0000 2019               1              0
# 22  Sat Mar 30 23:59:35 +0000 2019               1              0
# 23  Sat Mar 30 23:59:34 +0000 2019               0              0
# 24  Sat Mar 30 23:59:32 +0000 2019               4              0
# 25  Sat Mar 30 23:59:31 +0000 2019               2              0
# 26  Sat Mar 30 23:59:29 +0000 2019               0              4
# 27  Sat Mar 30 23:59:29 +0000 2019               2              0
# 28  Sat Mar 30 23:59:28 +0000 2019               4              0
# 29  Sat Mar 30 23:59:26 +0000 2019               1              1
# ..                             ...             ...            ...
# 70  Sat Mar 30 23:57:04 +0000 2019               0            818
# 71  Sat Mar 30 23:57:02 +0000 2019               0           1048
# 72  Sat Mar 30 23:57:02 +0000 2019               0             75
# 73  Sat Mar 30 23:56:57 +0000 2019               0            289
# 74  Sat Mar 30 23:56:55 +0000 2019               0           1604
# 75  Sat Mar 30 23:56:48 +0000 2019               0            509
# 76  Sat Mar 30 23:56:47 +0000 2019               2              0
# 77  Sat Mar 30 23:56:47 +0000 2019               0              7
# 78  Sat Mar 30 23:56:41 +0000 2019               0              0
# 79  Sat Mar 30 23:56:34 +0000 2019               0              0
# 80  Sat Mar 30 23:56:28 +0000 2019               0              1
# 81  Sat Mar 30 23:56:21 +0000 2019               0              0
# 82  Sat Mar 30 23:56:20 +0000 2019               0              0
# 83  Sat Mar 30 23:56:10 +0000 2019               0              0
# 84  Sat Mar 30 23:56:09 +0000 2019               0              1
# 85  Sat Mar 30 23:56:04 +0000 2019               0             20
# 86  Sat Mar 30 23:56:03 +0000 2019               0             82
# 87  Sat Mar 30 23:56:00 +0000 2019               0              0
# 88  Sat Mar 30 23:56:00 +0000 2019               0             78
# 89  Sat Mar 30 23:55:58 +0000 2019               1              0
# 90  Sat Mar 30 23:55:51 +0000 2019               0              0
# 91  Sat Mar 30 23:55:51 +0000 2019               0             20
# 92  Sat Mar 30 23:55:51 +0000 2019               0             20
# 93  Sat Mar 30 23:55:50 +0000 2019               0            618
# 94  Sat Mar 30 23:55:49 +0000 2019               0              0
# 95  Sat Mar 30 23:55:48 +0000 2019               0             20
# 96  Sat Mar 30 23:55:44 +0000 2019               0              1
# 97  Sat Mar 30 23:55:44 +0000 2019               0             75
# 98  Sat Mar 30 23:55:43 +0000 2019               1              1
# 99  Sat Mar 30 23:55:41 +0000 2019               0              0
#
#                                                  text  \
# 0   MIAMI, ARE YOU READY?\n\nOnly 2 more days unti...
# 1                    WE COULD BE HEROES\n\n#Ultra2019
# 2   Are you ready for #Ultra2019?🙌 Get in the mood...
# 3   RT @lllucia_: PARDON MY FRENCH IN THE HOUSE. @...
# 4                        FATHER OF HOUSEEE #Ultra2019
# 5   RT @RafaaFreitass: LOOK AT THIS VIEW \n\n#ULTR...
# 6   I love the church of @iamTchami #UltraMiami201...
# 7                           NOBODY ELSE\n\n#ULTRA2019
# 8   RT @DylanBrett00: #ultra2019 80k people strand...
# 9                     NOBODY ELSE #Ultra2019 #UMF2019
# 10       @iamTchami crushing it @ultra #Ultra2019 🙌🙌🙌
# 11  RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2....
# 12                         AWESOME music!  #Ultra2019
# 13                #ultra2019 let’s goooo from Russia)
# 14                     NOBODY ELSEEEEEEEEE #ULTRA2019
# 15  RT @UMFTV: Put your hands up for Tchami at #Ul...
# 16  LOOK AT THIS VIEW \n\n#ULTRA2019 https://t.co/...
# 17  RT @EDMManiac: BREAKING: multiple reports of a...
# 18                 Ultra is my religion ❤️ #Ultra2019
# 19                      dat tchami visual  #ultra2019
# 20  Not at #Ultra2019 but doing the next best thin...
# 21                          NOBODYELSEEEEE #ULTRA2019
# 22              #Ultra2019 Waiting for Martin Garrix!
# 23  Day 2 Ultra Live Steam. Let's get it 😘 #ultra2019
# 24                       #Ultra2019 heeeeeeyyy tchami
# 25           Nobody else, Nobody else 🔥 #ULTRA2019 🇺🇸
# 26  RT @edmalertcom: Ultra Music Festival Live Set...
# 27                            NOBODY ELSEE #Ultra2019
# 28  If I can’t have you,\nI don’t want nobody else...
# 29            TCHAMI is on! #Ultra2019 ♥ \nYaaaay!!!!
# ..                                                ...
# 70        RT @ultra: WE COULD BE HEROES\n\n#Ultra2019
# 71  RT @dancingastro: Ultra day 2 is already snapp...
# 72  RT @widefuture: Street artist, Royal Dog, is p...
# 73  RT @ultra: Wow, @SHAQ and @LilJon are on stage...
# 74  RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2....
# 75  RT @Tidoublemy8: Tens of thousands of people l...
# 76  My grandma is better than yours bc she have me...
# 77  RT @lllucia_: DON'T LET ME DOWN❤ #Ultra2019 #U...
# 78                                GO GO GO #Ultra2019
# 79                     Tchami is killin it #Ultra2019
# 80  RT @SexyCre4tivee: Jumpppppp Mother fuckers!!!...
# 81               @iamTchami is my father!! #Ultra2019
# 82  I'd hate to be those walking miles back to the...
# 83                  Let's go our frenchy ! #Ultra2019
# 84  RT @Menjivar019: PARDON MY FRENCH. 🇫🇷🇫🇷 @iamTc...
# 85  RT @FestEnfurecido: Skyline #Ultra2019 https:/...
# 86  RT @ultra: - Implementing comprehensive transp...
# 87  #ultra2019  this was set with @iamTchami https...
# 88  RT @ultra: We have been hard at work ensuring ...
# 89  Thanks for the stream @diplo @Carl_Cox 🔥🔥🔥🕺 #U...
# 90        #ultra2019 is trash for doing that KFC shit
# 91  RT @FestEnfurecido: Skyline #Ultra2019 https:/...
# 92  RT @FestEnfurecido: Skyline #Ultra2019 https:/...
# 93  RT @ultra: Thank you, Miami, for an unforgetta...
# 94                   I LOVE YOU @iamTchami #Ultra2019
# 95  RT @FestEnfurecido: Skyline #Ultra2019 https:/...
# 96  RT @SexyCre4tivee: Beautiful view!!❤️❤️❤️ #Ult...
# 97  RT @widefuture: Street artist, Royal Dog, is p...
# 98     Jumpppppp Mother fuckers!!!! 🙌🏼🙌🏼🙌🏼 #Ultra2019
# 99                       Don't let me down #Ultra2019
#
#                                              entities
# 0   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 1   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 2   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 3   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 4   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 5   {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 6   {'hashtags': [{'text': 'UltraMiami2019', 'indi...
# 7   {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 8   {'hashtags': [{'text': 'ultra2019', 'indices':...
# 9   {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 10  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 11  {'hashtags': [], 'symbols': [], 'user_mentions...
# 12  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 13  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 14  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 15  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 16  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 17  {'hashtags': [], 'symbols': [], 'user_mentions...
# 18  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 19  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 20  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 21  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 22  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 23  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 24  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 25  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 26  {'hashtags': [{'text': 'Tiesto', 'indices': [5...
# 27  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 28  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 29  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# ..                                                ...
# 70  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 71  {'hashtags': [{'text': 'ULTRA2019', 'indices':...
# 72  {'hashtags': [{'text': 'Ultralive', 'indices':...
# 73  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 74  {'hashtags': [], 'symbols': [], 'user_mentions...
# 75  {'hashtags': [], 'symbols': [], 'user_mentions...
# 76  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 77  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 78  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 79  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 80  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 81  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 82  {'hashtags': [{'text': 'UltraMiami2019', 'indi...
# 83  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 84  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 85  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 86  {'hashtags': [], 'symbols': [], 'user_mentions...
# 87  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 88  {'hashtags': [], 'symbols': [], 'user_mentions...
# 89  {'hashtags': [{'text': 'UltraMiami2019', 'indi...
# 90  {'hashtags': [{'text': 'ultra2019', 'indices':...
# 91  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 92  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 93  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 94  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 95  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 96  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 97  {'hashtags': [{'text': 'Ultralive', 'indices':...
# 98  {'hashtags': [{'text': 'Ultra2019', 'indices':...
# 99  {'hashtags': [{'text': 'Ultra2019', 'indices':...
#
# [100 rows x 5 columns]

# %%
analysis = TextBlob('Mood when they cut off Illenium’s set during the Ultra Live Stream. #Ultra2019')

# %%
print(analysis.sentiment)
# Out:
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)

# %%
polarity=[]
subjectivity=[]
sentiment=[]

for tweet in df_clean['text']:
    print(tweet)
    analysis = TextBlob(tweet)
    print(analysis.sentiment)
    
    polarity.append(analysis.sentiment[0])
    subjectivity.append(analysis.sentiment[1])
    
    if analysis.sentiment[0]>0:
        sentiment.append('Positive')
    elif analysis.sentiment[0]<0:
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
# Out:
# MIAMI, ARE YOU READY?
#
# Only 2 more days until #Ultra2019 https://t.co/NBGoNmTzwO
# Sentiment(polarity=0.2333333333333333, subjectivity=0.6666666666666666)
# WE COULD BE HEROES
#
# #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# Are you ready for #Ultra2019?🙌 Get in the mood and relive my @Ultra sets on my YouTube channel!
# Watch here ➡️… https://t.co/gxT65JfKiD
# Sentiment(polarity=0.25, subjectivity=0.5)
# RT @lllucia_: PARDON MY FRENCH IN THE HOUSE. @iamTchami 🙏🔥 #Ultra2019 #ULTRALIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# FATHER OF HOUSEEE #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @RafaaFreitass: LOOK AT THIS VIEW
#
# #ULTRA2019 https://t.co/W7krqUijGV
# Sentiment(polarity=0.0, subjectivity=0.0)
# I love the church of @iamTchami #UltraMiami2019 #Ultra2019 https://t.co/PEPcz06F8d
# Sentiment(polarity=0.5, subjectivity=0.6)
# NOBODY ELSE
#
# #ULTRA2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DylanBrett00: #ultra2019 80k people stranded on Virginia Key at Fyre Fest https://t.co/mnok1oGcke
# Sentiment(polarity=0.0, subjectivity=1.0)
# NOBODY ELSE #Ultra2019 #UMF2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# @iamTchami crushing it @ultra #Ultra2019 🙌🙌🙌
# Sentiment(polarity=0.4, subjectivity=0.9)
# RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2.0?
#
# Only one way off this island at 2am w/ zero transportation. 80k+ people stranded. #Ultra2…
# Sentiment(polarity=0.0, subjectivity=1.0)
# AWESOME music!  #Ultra2019
# Sentiment(polarity=1.0, subjectivity=1.0)
# #ultra2019 let’s goooo from Russia)
# Sentiment(polarity=0.0, subjectivity=0.0)
# NOBODY ELSEEEEEEEEE #ULTRA2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @UMFTV: Put your hands up for Tchami at #Ultra2019 You don't want to miss this one 👉 https://t.co/ZlHHKSQ7JE https://t.co/U4MlozHhpp
# Sentiment(polarity=0.0, subjectivity=0.0)
# LOOK AT THIS VIEW
#
# #ULTRA2019 https://t.co/W7krqUijGV
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @EDMManiac: BREAKING: multiple reports of an accident on the only shuttle bus route have left caused shuttles from Ultra to completely s…
# Sentiment(polarity=0.025, subjectivity=0.35)
# Ultra is my religion ❤️ #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# dat tchami visual  #ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# Not at #Ultra2019 but doing the next best thing, streaming it live online! Can’t wait to catch some of my favorites tonight
# Sentiment(polarity=0.39015151515151514, subjectivity=0.26666666666666666)
# NOBODYELSEEEEE #ULTRA2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# #Ultra2019 Waiting for Martin Garrix!
# Sentiment(polarity=0.0, subjectivity=0.0)
# Day 2 Ultra Live Steam. Let's get it 😘 #ultra2019
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# #Ultra2019 heeeeeeyyy tchami
# Sentiment(polarity=0.0, subjectivity=0.0)
# Nobody else, Nobody else 🔥 #ULTRA2019 🇺🇸
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @edmalertcom: Ultra Music Festival Live Sets:
#
# #Tiesto
# #Alesso
# #Marshmello
# #Skrillex x #diplo
# #SamFeldt
# #Malaa
# #NoraEnPure
# #Nicky…
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# NOBODY ELSEE #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# If I can’t have you,
# I don’t want nobody else🎶
#
# @iamTchami #ULTRA2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# TCHAMI is on! #Ultra2019 ♥
# Yaaaay!!!!
# Sentiment(polarity=1.0, subjectivity=1.0)
# Ultra's Mainstage is a thing of beauty
#
# #Ultra2019 #UltraMiami2019 #ultramiami #ULTRALIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# BASS HOUSE GOD 👑 @iamTchami  #Ultra2019 🔥🔥🔥
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.5)
# Fuck me up  #Ultra2019
# Sentiment(polarity=-0.4, subjectivity=0.6)
# RT @eaerasta1: Waiting for ma boy🧡 #Ultra2019 #Illenium https://t.co/NI2q0O2ULt
# Sentiment(polarity=0.0, subjectivity=0.0)
# Nobody else #ULTRA2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# @iamTchami makes my heart so happy #ultra2019
# Sentiment(polarity=0.8, subjectivity=1.0)
# RT @UMFTV: Put your hands up for Tchami at #Ultra2019 You don't want to miss this one 👉 https://t.co/ZlHHKSQ7JE https://t.co/U4MlozHhpp
# Sentiment(polarity=0.0, subjectivity=0.0)
# Woooow @iamTchami  at @ultra  Is just amazing what a set #ultra2019 #ULTRALIVE some day
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
# RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2.0?
#
# Only one way off this island at 2am w/ zero transportation. 80k+ people stranded. #Ultra2…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @ultra: Catch all the action from Day 2 of #Ultra2019 on ULTRA LIVE today beginning at 5pm EDT!
#
# https://t.co/SCzbHpfuds https://t.co/7v…
# Sentiment(polarity=0.13522727272727272, subjectivity=0.3)
# Aaaaaaaa nobody else #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @dancingastro: Ultra day 2 is already snapping... @NGHTMRE B2B @SlanderOfficial B2B @SHAQ 👀 #ULTRA2019
#
# 🎥: @1001TLtv
#
# https://t.co/iUQfD…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Please my live feed of me shuffling at home @iamTchami. You the best!!!!! #Ultra2019
# Sentiment(polarity=0.5681818181818181, subjectivity=0.4)
# RT @UMFTV: Put your hands up for Tchami at #Ultra2019 You don't want to miss this one 👉 https://t.co/ZlHHKSQ7JE https://t.co/U4MlozHhpp
# Sentiment(polarity=0.0, subjectivity=0.0)
# @AudioChromatic It was very nice I have to say.  Now back home and blowing my speakers out with #ultra2019 . 🔉🔉🔉🔥
# Sentiment(polarity=0.39, subjectivity=0.5)
# RT @dancingastro: Ultra day 2 is already snapping... @NGHTMRE B2B @SlanderOfficial B2B @SHAQ 👀 #ULTRA2019
#
# 🎥: @1001TLtv
#
# https://t.co/iUQfD…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Let's go ultra!! #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @UMFTV: Put your hands up for Tchami at #Ultra2019 You don't want to miss this one 👉 https://t.co/ZlHHKSQ7JE https://t.co/U4MlozHhpp
# Sentiment(polarity=0.0, subjectivity=0.0)
# TCHAMI IS ON FIREEE 🥰 #ULTRA2019 🇺🇸
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Tidoublemy8: Tens of thousands of people leaving @Ultra to walk 3 miles across a bridge (blocking traffic) because it was the only real…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @FestEnfurecido: Skyline #Ultra2019 https://t.co/6qcL2kn0XX
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ultra: Thank you, Miami, for an unforgettable first day!!!
#
# Who's ready for day 2??
#
# #Ultra2019 https://t.co/K3fnL75AsF
# Sentiment(polarity=0.49609375, subjectivity=0.611111111111111)
# RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2.0?
#
# Only one way off this island at 2am w/ zero transportation. 80k+ people stranded. #Ultra2…
# Sentiment(polarity=0.0, subjectivity=1.0)
# Nobody Else
# #ULTRA2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# OHHHH! Nobody Else do Axwell!!!! #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# @iamTchami Smack my ears up!!  #ULTRA2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# FOR KEITH #Tchami #ultra2019 THANK YOU
# Sentiment(polarity=0.0, subjectivity=0.0)
# PARADISEEEE #Ultra2019 https://t.co/9JmYxDgrw8
# Sentiment(polarity=0.0, subjectivity=0.0)
# RIP KEITH FLINT #ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# Get your own custom flag now, dm us ❤️ #ultra2019 #musicproducer #producer #deephouse #deep #LoveWins #love… https://t.co/O0E5E0kj9i
# Sentiment(polarity=0.3, subjectivity=0.7)
# SMACK MY BITCH UP #Ultra2019 #Ultra
# Sentiment(polarity=0.0, subjectivity=0.0)
# In love @iamTchami 🤪❤️ #Ultra2019
# Sentiment(polarity=0.5, subjectivity=0.6)
# RT @marialagunaaa: SUNSHINE IN THE CHURCH #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2.0?
#
# Only one way off this island at 2am w/ zero transportation. 80k+ people stranded. #Ultra2…
# Sentiment(polarity=0.0, subjectivity=1.0)
# Shit beautiful... ❤️ #Ultra2019 https://t.co/ZjfdimAV3T
# Sentiment(polarity=0.32499999999999996, subjectivity=0.9)
# SUNSHINE IN THE CHURCH #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# https://t.co/SBZaSOAdo0 @iamTchami had me in the house like #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @lllucia_: PARDON MY FRENCH IN THE HOUSE. @iamTchami 🙏🔥 #Ultra2019 #ULTRALIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ultra fans, send a hug to my grandma #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# That B2B with Carl Cox and Marco Carola will be awesome!! #Ultra2019
# Sentiment(polarity=1.0, subjectivity=1.0)
# RT @ultra: WE COULD BE HEROES
#
# #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @dancingastro: Ultra day 2 is already snapping... @NGHTMRE B2B @SlanderOfficial B2B @SHAQ 👀 #ULTRA2019
#
# 🎥: @1001TLtv
#
# https://t.co/iUQfD…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @widefuture: Street artist, Royal Dog, is painting a mural at Ultra in memory of late Avicii! #Ultralive #Ultra2019 https://t.co/ET1YQJY…
# Sentiment(polarity=-0.375, subjectivity=0.6)
# RT @ultra: Wow, @SHAQ and @LilJon are on stage with @NGHTMRE + @SlanderOfficial present Gud Vibrations for one 🔥 sunset! #Ultra2019
# Sentiment(polarity=0.05, subjectivity=0.5)
# RT @BWilliams_38: .@ultra 2019 or Fyre Fest 2.0?
#
# Only one way off this island at 2am w/ zero transportation. 80k+ people stranded. #Ultra2…
# Sentiment(polarity=0.0, subjectivity=1.0)
# RT @Tidoublemy8: Tens of thousands of people leaving @Ultra to walk 3 miles across a bridge (blocking traffic) because it was the only real…
# Sentiment(polarity=0.0, subjectivity=1.0)
# My grandma is better than yours bc she have me queques! #Ultra2019
# Sentiment(polarity=0.625, subjectivity=0.5)
# RT @lllucia_: DON'T LET ME DOWN❤ #Ultra2019 #ULTRALIVE
# Sentiment(polarity=0.0, subjectivity=0.0)
# GO GO GO #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# Tchami is killin it #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @SexyCre4tivee: Jumpppppp Mother fuckers!!!! 🙌🏼🙌🏼🙌🏼 #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# @iamTchami is my father!! #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# I'd hate to be those walking miles back to the car.
# #UltraMiami2019 #UltraMusicFestival #Ultra2019 https://t.co/zZHVjXBAs5
# Sentiment(polarity=-0.4, subjectivity=0.45)
# Let's go our frenchy ! #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @Menjivar019: PARDON MY FRENCH. 🇫🇷🇫🇷 @iamTchami  #Ultra2019 #ULTRALIVE https://t.co/k8YmYqxkmK
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @FestEnfurecido: Skyline #Ultra2019 https://t.co/6qcL2kn0XX
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ultra: - Implementing comprehensive transportation information, including this exit map, at every shuttle hub and around the festival.…
# Sentiment(polarity=0.0, subjectivity=0.0)
# #ultra2019  this was set with @iamTchami https://t.co/nqsTD4i556
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ultra: We have been hard at work ensuring a smooth transportation experience for your trip home after the festival tonight.
#
# Specific a…
# Sentiment(polarity=0.036111111111111115, subjectivity=0.38888888888888884)
# Thanks for the stream @diplo @Carl_Cox 🔥🔥🔥🕺 #UltraMiami2019 #ULTRA2019 https://t.co/SSUTqms69D
# Sentiment(polarity=0.2, subjectivity=0.2)
# #ultra2019 is trash for doing that KFC shit
# Sentiment(polarity=-0.2, subjectivity=0.8)
# RT @FestEnfurecido: Skyline #Ultra2019 https://t.co/6qcL2kn0XX
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @FestEnfurecido: Skyline #Ultra2019 https://t.co/6qcL2kn0XX
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @ultra: Thank you, Miami, for an unforgettable first day!!!
#
# Who's ready for day 2??
#
# #Ultra2019 https://t.co/K3fnL75AsF
# Sentiment(polarity=0.49609375, subjectivity=0.611111111111111)
# I LOVE YOU @iamTchami #Ultra2019
# Sentiment(polarity=0.5, subjectivity=0.6)
# RT @FestEnfurecido: Skyline #Ultra2019 https://t.co/6qcL2kn0XX
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @SexyCre4tivee: Beautiful view!!❤️❤️❤️ #Ultra2019
# Sentiment(polarity=0.85, subjectivity=1.0)
# RT @widefuture: Street artist, Royal Dog, is painting a mural at Ultra in memory of late Avicii! #Ultralive #Ultra2019 https://t.co/ET1YQJY…
# Sentiment(polarity=-0.375, subjectivity=0.6)
# Jumpppppp Mother fuckers!!!! 🙌🏼🙌🏼🙌🏼 #Ultra2019
# Sentiment(polarity=0.0, subjectivity=0.0)
# Don't let me down #Ultra2019
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)

# %%
df_clean["Sentiment"]=pd.Series(sentiment)
# Out:
# C:\Users\danie\Anaconda3\envs\pythonrules\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_clean["Polarity"]=pd.Series(polarity)
df_clean["Subjectivity"]=pd.Series(subjectivity)
df_clean.head(1)
# Out:
# C:\Users\danie\Anaconda3\envs\pythonrules\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\danie\Anaconda3\envs\pythonrules\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        created_at  favorite_count  retweet_count  \
# 0  Wed Mar 27 16:23:20 +0000 2019            4135           1016
#
#                                                 text  \
# 0  MIAMI, ARE YOU READY?\n\nOnly 2 more days unti...
#
#                                             entities Sentiment  Polarity  \
# 0  {'hashtags': [{'text': 'Ultra2019', 'indices':...  Positive  0.233333
#
#    Subjectivity
# 0      0.666667

# %%
s=df_clean.groupby('Sentiment').count()
print(s["created_at"])
# Out:
# Sentiment
# Negative     7
# Neutral     66
# Positive    27
# Name: created_at, dtype: int64

# %%
labels = 'Negative','Neutral','Positive'
sizes = [s["created_at"][0],s["created_at"][1],s["created_at"][2]]
colors = ['lightcoral', 'gold','yellowgreen' ]
explode = (0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
df_clean.plot(x="created_at",y="Polarity")

# %%
#sentiment in time

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
ts
# Out:
# 2019-01-01    NaN
# 2019-01-02    NaN
# 2019-01-03    NaN
# 2019-01-04    NaN
# 2019-01-05    NaN
# 2019-01-06    NaN
# 2019-01-07    NaN
# 2019-01-08    NaN
# 2019-01-09    NaN
# 2019-01-10    NaN
# 2019-01-11    NaN
# 2019-01-12    NaN
# 2019-01-13    NaN
# 2019-01-14    NaN
# 2019-01-15    NaN
# 2019-01-16    NaN
# 2019-01-17    NaN
# 2019-01-18    NaN
# 2019-01-19    NaN
# 2019-01-20    NaN
# 2019-01-21    NaN
# 2019-01-22    NaN
# 2019-01-23    NaN
# 2019-01-24    NaN
# 2019-01-25    NaN
# 2019-01-26    NaN
# 2019-01-27    NaN
# 2019-01-28    NaN
# 2019-01-29    NaN
# 2019-01-30    NaN
#              ...
# 2019-03-02    NaN
# 2019-03-03    NaN
# 2019-03-04    NaN
# 2019-03-05    NaN
# 2019-03-06    NaN
# 2019-03-07    NaN
# 2019-03-08    NaN
# 2019-03-09    NaN
# 2019-03-10    NaN
# 2019-03-11    NaN
# 2019-03-12    NaN
# 2019-03-13    NaN
# 2019-03-14    NaN
# 2019-03-15    NaN
# 2019-03-16    NaN
# 2019-03-17    NaN
# 2019-03-18    NaN
# 2019-03-19    NaN
# 2019-03-20    NaN
# 2019-03-21    NaN
# 2019-03-22    NaN
# 2019-03-23    NaN
# 2019-03-24    NaN
# 2019-03-25    NaN
# 2019-03-26    NaN
# 2019-03-27    NaN
# 2019-03-28    NaN
# 2019-03-29    NaN
# 2019-03-30    NaN
# 2019-03-31    NaN
# Freq: D, Name: created_at, Length: 90, dtype: object

# %%
import time
ts1=[]
for tweet in df_clean['created_at']:
    ts1.append(time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(tweet,'%a %b %d %H:%M:%S +0000 %Y')))
df_clean["time"]=pd.Series(ts1)
df_clean.head(1)
# Out:
# C:\Users\danie\Anaconda3\envs\pythonrules\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                        created_at  favorite_count  retweet_count  \
# 0  Mon Apr 01 14:25:18 +0000 2019            2218            472
#
#                                                 text Sentiment  Polarity  \
# 0  My @ultra Miami set is here! https://t.co/pVMT...   Neutral       0.0
#
#    Subjectivity                 time
# 0           0.0  2019-04-01 14:25:18

# %%
df_sort=df_clean.sort_values(by='time')
df_sort=df_sort.reset_index()
df_sort.head(10)
# Out:
#    index                      created_at  favorite_count  retweet_count  \
# 0      2  Mon Apr 01 08:07:24 +0000 2019            3094            391
# 1      0  Mon Apr 01 14:25:18 +0000 2019            2218            472
# 2      1  Tue Apr 02 04:46:34 +0000 2019            1218            193
# 3     99  Wed Apr 03 01:01:33 +0000 2019               0              6
# 4     98  Wed Apr 03 01:02:02 +0000 2019               1              0
# 5     97  Wed Apr 03 01:02:32 +0000 2019               0           1025
# 6     96  Wed Apr 03 01:03:18 +0000 2019               0            502
# 7     95  Wed Apr 03 01:03:18 +0000 2019               0            502
# 8     94  Wed Apr 03 01:03:19 +0000 2019               0            502
# 9     93  Wed Apr 03 01:03:37 +0000 2019               0            502
#
#                                                 text Sentiment  Polarity  \
# 0  THANK YOU @ultra ❤️❤️ #ULTRA2019 #Afrojack htt...   Neutral  0.000000
# 1  My @ultra Miami set is here! https://t.co/pVMT...   Neutral  0.000000
# 2  ULTRA 2019!! ❤️ Full set is now live on my You...  Positive  0.260227
# 3  RT @EDMManiac: Despite the initial hiccups, #U...   Neutral  0.000000
# 4  That’s family right there #ULTRA2019 https://t...  Positive  0.285714
# 5  RT @dancingastro: Ultra day 2 is already snapp...   Neutral  0.000000
# 6  RT @arilinares10: Hey Twitter I need your help...  Positive  0.700000
# 7  RT @arilinares10: Hey Twitter I need your help...  Positive  0.700000
# 8  RT @arilinares10: Hey Twitter I need your help...  Positive  0.700000
# 9  RT @arilinares10: Hey Twitter I need your help...  Positive  0.700000
#
#    Subjectivity                 time
# 0      0.000000  2019-04-01 08:07:24
# 1      0.000000  2019-04-01 14:25:18
# 2      0.525000  2019-04-02 04:46:34
# 3      0.375000  2019-04-03 01:01:33
# 4      0.535714  2019-04-03 01:02:02
# 5      0.000000  2019-04-03 01:02:32
# 6      0.900000  2019-04-03 01:03:18
# 7      0.900000  2019-04-03 01:03:18
# 8      0.900000  2019-04-03 01:03:19
# 9      0.900000  2019-04-03 01:03:37

# %%
df_sort["time"] = pd.to_datetime(df_sort['time'])
df_sort.plot(x="time", y=["Polarity","Subjectivity"])
plt.show()
